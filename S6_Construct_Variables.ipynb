# %% [markdown]
# ### Construct DataFrame

# %%
import pandas as pd
import json

def dataframe_construct(input_file_path, output_file_path):
    # Read JSON file
    with open(input_file_path, 'r', encoding='utf-8') as file:
        # Load JSON data
        data = json.load(file)
        
    # Initialize lists to store story_id and body_text
    story_ids = []
    body_texts = []

    # Process each story in the JSON data
    for idx, story in enumerate(data):
        # Extract story_id and body_text
        story_id = idx + 1  # Assuming story_id starts from 1
        body_text = story.strip('"')  # Remove leading/trailing quotes
        
        # Append to lists
        story_ids.append(story_id)
        body_texts.append(body_text)

    # Create DataFrame
    df = pd.DataFrame({'Story_ID': story_ids, 'Body_text': body_texts})

    # Save DataFrame to CSV with headers and without index column
    df.to_csv(output_file_path, index=False, header=True)
    
    # Read CSV file
    df_csv = pd.read_csv(output_file_path)

    # Print first 10 words of each body_text
    print("Printing first 10 words of each story:")
    for index, row in df_csv.iterrows():
        first_10_words = ' '.join(row['Body_text'].split()[:10])
        print(f"Story {row['Story_ID']}, {first_10_words}...")
        print()  # Separate each story

# Example usage
input_file_path = 'tokenizedFine_500.json'
output_file_path = 'df_construct_500.csv'
dataframe_construct(input_file_path, output_file_path)
# Out:
# Printing first 10 words of each story:
# Story 1, bengaluru infosys solid foundation grow back large deal bagged fiscal...
#
# Story 2, december staff american writer artist institute membership organization copywriter realized...
#
# Story 3, bengaluru genz prioritizes professional growth competitive pay workplace consideration continuing...
#
# Story 4, new technology upend many online business company figure work boon...
#
# Story 5, share u tech giant buzzing fund scorching performance chart mirae...
#
# Story 6, every tuesday friday ezra klein invite conversation something matter today...
#
# Story 7, door shut andrew return mark andrew raven star tight end...
#
# Story 8, doha mekki one president biden key antitrust enforcer talk justice...
#
# Story 9, general election campaign begin earnest expect disinformation attack target voter...
#
# Story 10, reddit social medium news aggregation platform million active daily user...
#
# Story 11, tech giant partner openai accused infringing copyright train technology online...
#
# Story 12, rise popular new chatbot chatgpt college restructuring course taking preventive...
#
# Story 13, customer engagement loyalty software provider capillary technology extended latest series...
#
# Story 14, go vacation summer question simple enough possibility endless feeling adventurous...
#
# Story 15, million article new york time used train chatbots compete lawsuit...
#
# Story 16, december staff american writer artist institute membership organization copywriter realized...
#
# Story 17, artificial intelligence continues advance grasp human human following suit starting...
#
# Story 18, steam power internet always lag technology invention adoption across industry...
#
# Story 19, abstract program generate image almost anything maker plan hope make...
#
# Story 20, johnny taylor tackle human resource question part series usa today...
#
# Story 21, grammarly company provides eponymous grammar syntax program recently announced getting...
#
# Story 22, bard google conversational generative artificial intelligence chatbot rolled country including...
#
# Story 23, correction clarification earlier version column incorrectly attributed source generative ai...
#
# Story 24, claim image show first seance toy ouija board april facebook...
#
# Story 25, department homeland security seen opportunity risk artificial intelligence firsthand found...
#
# Story 26, product pitched helpmate journalist demonstrated executive new york time washington...
#
# Story 27, nasscom chief debjani ghosh body new delhi india potential artificial...
#
# Story 28, venture capital firm focused deep tech sector reinforcing presence india...
#
# Story 29, partnership extend long relationship company helped deliver everything map search...
#
# Story 30, valuation tripled le month openai completed deal value san francisco...
#
# Story 31, amazon box salesforce oracle others recently rolled product help workplace...
#
# Story 32, everyone seems complain hard get good help day even artificial...
#
# Story 33, francis become recurring favorite show incongruous situation riding motorcycle attending...
#
# Story 34, abstract business facing influx new artificial intelligence tool many overlap...
#
# Story 35, regulation amazon challenge digital standard amazon disputing status big online...
#
# Story 36, reid hoffman founder linkedin longtime venture capitalist longer public face...
#
# Story 37, tech firm google microsoft loggerhead time google pushing antitrust action...
#
# Story 38, many uncertainty haunt field journalism today among reach audience build...
#
# Story 39, addressing lower business demand best buy made significant cut workforce...
#
# Story 40, society need sound government policy promote progress reducing risk abuse...
#
# Story 41, abstract charlie munger speaking berkshire hathaway annual shareholder meeting say...
#
# Story 42, internal meeting chief executive explained plan artificial intelligence metaverse rebooting...
#
# Story 43, product pitched helpmate journalist demonstrated executive new york time washington...
#
# Story 44, bengaluru disprz corporate learning skilling platform raised million series funding...
#
# Story 45, abstract chen personal journal column note worker especially freelancer owner...
#
# Story 46, tool chatgpt open new line question around tech product harmful...
#
# Story 47, world leader gather swiss alp year war trade risk disruptive...
#
# Story 48, openai ceo sam altman picked japan destination first overseas trip...
#
# Story 49, set advance rapid rate becoming powerful spreading physical world event...
#
# Story 50, reception openai first developer conference san francisco last month crowd...
#
# Story 51, abstract afarin bellisario letter responds peggy noonan april declaration column...
#
# Story 52, jeff maggioncalda ceo coursera new delhi access digital education gamechanger...
#
# Story 53, johnny taylor tackle human resource question part series usa today...
#
# Story 54, agricultural ai startup kissan ai founder pratik desai last month...
#
# Story 55, chafing dependence amazon google meta microsoft racing cut nvidia dominant...
#
# Story 56, new delhi deeptech digital public infrastructure dpi data artificial intelligence...
#
# Story 57, jason kwon chief strategy officer openai new delhi country global...
#
# Story 58, investment billion amazon seeking bigger footprint development one already established...
#
# Story 59, india world trillion worth compute infrastructure several time le country...
#
# Story 60, several experimental generative artificial intelligence genai project expected go live...
#
# Story 61, long technology rival chatbots chatgpt afford back artificial intelligence spread...
#
# Story 62, mumbai increasing number ceo cxos top management professional seeking upskill...
#
# Story 63, information technology company increasingly building capability advanced generative artificial intelligence...
#
# Story 64, nation head presidential election independent body review meta content moderation...
#
# Story 65, major technology company signed pact friday voluntarily adopt reasonable precaution...
#
# Story 66, company discussed multiyear deal worth least million train generative system...
#
# Story 67, ad meant show updated device many thing become metaphor community...
#
# Story 68, francis become recurring favorite show incongruous situation riding motorcycle attending...
#
# Story 69, accenture first quarter performance guidance second quarter announced tuesday bode...
#
# Story 70, many site get least half traffic search engine fuller result...
#
# Story 71, delhi infosys highest nifty weighting among locally listed technology company...
#
# Story 72, gary gensler studied consequence artificial intelligence year technology lead future...
#
# Story 73, able write still matter chatbots u teenager weigh essay opinion...
#
# Story 74, national security official warning potential new technology upend war cyber...
#
# Story 75, nvidia predicted another massive sale gain current quarter helping justify...
#
# Story 76, local college say using generative ai chatgpt classroom limitation teach...
#
# Story 77, country singer romance novelist video game artist voice actor appealing...
#
# Story 78, user instagram facebook whatsapp messenger able turn new technology powered...
#
# Story 79, artificial intelligence collaborated news organization time accused copyright infringement telling...
#
# Story 80, samsung highly anticipated galaxy unpacked event scheduled january san jose...
#
# Story 81, abstract michael chui article journal report innovation work contends generative...
#
# Story 82, whenever madonna sings hit la isla bonita concert tour moving...
#
# Story 83, collection free link help participating multimedia challenge high school education...
#
# Story 84, internet giant begin testing new chatbot bard small private group...
#
# Story 85, medicine tolerate gregory ator chief medical informatics officer university kansa...
#
# Story 86, department homeland security seen opportunity risk artificial intelligence firsthand found...
#
# Story 87, literary theory robot dennis yi tenen software engineer turned literature...
#
# Story 88, fan star lawmaker condemned image probably generated artificial intelligence shared...
#
# Story 89, move expand user base american tech giant microsoft made bing...
#
# Story 90, mumbai air india talk aerospace major including airbus potential partner...
#
# Story 91, latest version data bill drop clause created exception bengaluru generative...
#
# Story 92, new delhi deeptech digital public infrastructure dpi data artificial intelligence...
#
# Story 93, abstract artificial intelligence confronting professional directly ever make productive obsolete...
#
# Story 94, abstract trip beijing taiwan showed united state china fated cooperate...
#
# Story 95, accenture started see potential revenue upswing use generative artificial intelligence...
#
# Story 96, mountain view alphabet inc google conversational generative ai chatbot rolled...
#
# Story 97, anthropic san artificial intelligence startup founded sibling daniela dario amodei...
#
# Story 98, tiktok meta race flag remove hateful comment swirling platform generative...
#
# Story 99, five article around time narrated weekend listen collection article around...
#
# Story 100, ask chatgpt comedian sarah silverman memoir bedwetter artificial intelligence chatbot...
#
# Story 101, reprise april ted talk warned ai hacking human brain nita...
#
# Story 102, mumbai artificial intelligence ai replace fte technology role annually next...
#
# Story 103, new delhi edtech platform move towards deploying artificial intelligence tool...
#
# Story 104, year looking grim news business facing set harsh financial reality...
#
# Story 105, unionized allegheny general hospital nurse scheduled vote thursday whether continue...
#
# Story 106, abstract handful digital finding success far least learning lesson troubled...
#
# Story 107, new delhi nearly year openai chatgpt made wave leading artificial...
#
# Story 108, news union represents film television actor voted monday night authorize...
#
# Story 109, past two decade word startup become synonymous india today startup...
#
# Story 110, story syndicated substack newsletter big technology subscribe free recently new...
#
# Story 111, performance culminates production composed spot misguided help artificial intelligence artificial...
#
# Story 112, written lot year protect identity avoid becoming victim identity theft...
#
# Story 113, string gambling situation involving athlete leaf league tough spot major...
#
# Story 114, abstract david salle one america thoughtful painter want see algorithm...
#
# Story 115, abstract dan gallagher heard street column note boost given chip...
#
# Story 116, japanese telecommunication giant ntt corporation fully exited controlling stake consulting...
#
# Story 117, many ad easier make technology pose threat industry already flux...
#
# Story 118, startup ecosystem today remarkably different decade ago ecosystem expected get...
#
# Story 119, abstract artificial intelligence tool given scammer potent weapon trying trick...
#
# Story 120, seems competition getting tougher google wednesday announced finally opening access...
#
# Story 121, abstract betsy morris article journal report strategy note research finding...
#
# Story 122, amazon new factory worker complain long hour poor working condition...
#
# Story 123, abstract tiktok testing chatbot powered generative artificial intelligence designed help...
#
# Story 124, mumbai ai artificial intelligence may buzzword marketing right cxos seem...
#
# Story 125, year designer computer chip mainly used one tactic boost performance...
#
# Story 126, shopping walmart sam club get easier walmart tuesday unveiled several...
#
# Story 127, year tech world one big leap even bigger pratfall fall...
#
# Story 128, company assume legal risk business use system publish technology underlying...
#
# Story 129, mira murati openai chief technology officer brought question altman management...
#
# Story 130, step assume student going use technology last november chatgpt released...
#
# Story 131, bengaluru india fastest growing market microsoft github internet hosting service...
#
# Story 132, explainer explainer mumbai u leading race releasing generative ai large...
#
# Story 133, shock pause central bank spook already jittery market one analyst...
#
# Story 134, tech giant introduced rufus chatbot lagged behind others introducing generative...
#
# Story 135, saasboomi collective saas product company founder thursday marked enterprise value...
#
# Story 136, apple appeal penalty latest series regulatory setback tech giant apple...
#
# Story 137, according salesforce ceo marc benioff artificial intelligence important technology lifetime...
#
# Story 138, together fund led freshworks founder girish mathrubootham eka software founder...
#
# Story 139, washington michael cohen former attorney fixer former president donald trump...
#
# Story 140, tech giant apple laid employee across car smartwatch screen project...
#
# Story 141, conversational artificial intelligence ai startup monday announced official launch bharatgpt...
#
# Story 142, scott murray founder ceo activist investor trillium capital want getty...
#
# Story 143, school year begin thinking evolved sat chatgpt workshop month teacher...
#
# Story 144, past year digital artist refik anadol starred exhibition museum modern...
#
# Story 145, producer pop singer long proponent technological experimentation voice using new...
#
# Story 146, called perplexity show possible search engine built scratch artificial intelligence...
#
# Story 147, many site get least half traffic search engine fuller result...
#
# Story 148, april last year tiktok user wrote produced song called heart...
#
# Story 149, decade son luca diagnosed dyslexia scott sosso developed website help...
#
# Story 150, share fell friday asia japan reported economy grew le earlier...
#
# Story 151, abstract best use generative health care doctor say ease heavy...
#
# Story 152, abstract intuit released tool intuit assist offer customer financial recommendation...
#
# Story 153, community first marketed way celebrity text fan big brand board...
#
# Story 154, world machine crack joke compose sonnet term generative ai inevitably...
#
# Story 155, mumbai artificial intelligence ai replace fte technology role annually next...
#
# Story 156, alaska airline using generative ai turn natural language prompt want...
#
# Story 157, federal election commission begun process potentially regulate deepfakes political ad...
#
# Story 158, google close investing million homegrown conversational artificial intelligence startup people...
#
# Story 159, elon musk ceo twitter ev maker tesla planning launch new...
#
# Story 160, tech proponent say generative artificial intelligence revolutionize education yet school...
#
# Story 161, step assume student going use technology last november chatgpt released...
#
# Story 162, labor contract negotiation heat hollywood union representing writer actor seek...
#
# Story 163, steven spielberg science fiction film minority report set u showcase...
#
# Story 164, artificial intelligence act collaborator help artist produce new work personal...
#
# Story 165, tech leader faced grilling senate one offered apology skeptic fear...
#
# Story 166, tech giant unbundling team office software suite face mounting scrutiny...
#
# Story 167, abstract microsoft corp infusing popular workplace software technology behind viral...
#
# Story 168, celebration stability ai behind controversial stable diffusion image generator represents...
#
# Story 169, union agreed deal studio last month actor writer strike industry...
#
# Story 170, tech giant evaluating tool use artificial intelligence perform task researcher...
#
# Story 171, audio series platform pocket fm tuesday announced international expansion entry...
#
# Story 172, labor contract negotiation heat hollywood union representing writer actor seek...
#
# Story 173, abstract dan gallagher heard street column contends growing demand service...
#
# Story 174, sunday episode excerpt podcast unleashing powerful artificial intelligence world little...
#
# Story 175, spoke chinese baidu ernie american chatgpt found last month china...
#
# Story 176, thing dominating headline come generative ai right chatgpt yet lot...
#
# Story 177, chilly wednesday evening october sound filling ambre romero home familiar...
#
# Story 178, plus president biden talked xi jinping aid worker killed gaza...
#
# Story 179, every tuesday friday ezra klein invite conversation something matter today...
#
# Story 180, string uncanny video show generative advertising common chew cultural subconscious...
#
# Story 181, inquiry european regulator epic game apple allow access software tool...
#
# Story 182, abstract kartik hosnagar article journal report innovation work suggests important...
#
# Story 183, nonprofit allen institute ai led respected computer scientist sold company...
#
# Story 184, sundar pichai google chief executive testified tuesday second time two...
#
# Story 185, good morning daniel de visé daily money feel paycheck going...
#
# Story 186, last week found writing column touch rapid advance artificial intelligence...
#
# Story 187, abstract tool promise fix common red flag used identify bogus...
#
# Story 188, steam power internet always lag technology invention adoption across industry...
#
# Story 189, company invested billion generative pioneer openai say giant system necessarily...
#
# Story 190, berkshire hathaway shareholder gather omaha conglomerate annual meeting saturday question...
#
# Story 191, editor school cope grow student using kevin roose shift column...
#
# Story 192, board member hollywood actor union voted friday approve deal studio...
#
# Story 193, abstract pricewaterhousecoopers llp plan invest billion generative technology u operation...
#
# Story 194, openai ceo sam altman testify congress next tuesday lawmaker increasingly...
#
# Story 195, chandra first public comment mumbai tata consultancy service tc sacked...
#
# Story 196, corporate diversity equity inclusion program come attack company rebranding effort...
#
# Story 197, large company today specialised initiative focus diversity inclusion annual report...
#
# Story 198, concept jargon need understand chatgpt compiled list phrase concept useful...
#
# Story 199, ad meant show updated device many thing become metaphor community...
#
# Story 200, fan star lawmaker condemned image probably generated artificial intelligence shared...
#
# Story 201, sundance film festival launch edition later month welcoming back alumnus...
#
# Story 202, ceo meet iisc iit researcher bengaluru nvidia world maker hardware...
#
# Story 203, legislator two dozen state working bill passed law combat sexually...
#
# Story 204, bengaluru infosys chief executive salil parekh remuneration fell crore fiscal...
#
# Story 205, chatbots sentient underlying technology work microsoft released new version bing...
#
# Story 206, light space artist flew radar moment sun aesthetically los angeles...
#
# Story 207, microsoft plan invest billion emirati company tie china washington beijing...
#
# Story 208, amid overwhelming demand niche technology skill financial service industry india...
#
# Story 209, plan culmination yearlong listening tour danger new technology bipartisan group...
#
# Story 210, spend enough time chatgpt artificial intelligence chatbots take long spout...
#
# Story 211, ceo meet iisc iit researcher bengaluru nvidia world maker hardware...
#
# Story 212, ten million job automated generative artificial intelligence maker new technology...
#
# Story 213, steel paint ketchup pittsburgh oldest largest manufacturer learning automate operation...
#
# Story 214, altman whose sudden firing rehiring fall shocked silicon valley among...
#
# Story 215, user instagram facebook whatsapp messenger able turn new technology powered...
#
# Story 216, cincinnati major hospital system using artificial intelligence technology american wary...
#
# Story 217, core part portfolio make majority portfolio mix core satellite depends...
#
# Story 218, abstract company databricks agrees acquire startup mosaicml deal valued around...
#
# Story 219, new artificial intelligence technology roiling silicon valley obvious way use...
#
# Story 220, doctor office winery bistro dentist painter realtor small business pittsburgh...
#
# Story 221, country global institution must work together harmonise effort tackle issue...
#
# Story 222, san francisco valuation triple le six month openai talk complete...
#
# Story 223, business vinod khosla cofounder sun microsystems founder khosla venture called...
#
# Story 224, lawsuit cap year regulatory scrutiny apple wildly popular suite device...
#
# Story 225, humanity closer ever extinction according international expert nuclear technology cyber...
#
# Story 226, communist party outlined draft rule set guardrail rapidly growing industry...
#
# Story 227, company assume legal risk business use system publish technology underlying...
#
# Story 228, washington amazon google meta microsoft company leading development artificial intelligence...
#
# Story 229, lawmaker beginning contemplate question authorship ownership around creative machine stake...
#
# Story 230, inhibiting trade mean anywhere global gdp risk bob sternfels global...
#
# Story 231, demand outlook adverse expected mumbai share technology company saw relief...
#
# Story 232, focus much discussion replace job nothing inevitable easy fear machine...
#
# Story 233, financial service industry plotting incorporate tool chatgpt product human still...
#
# Story 234, company utilize strategic response management srm better chance winning rfp...
#
# Story 235, presidential primary underway across popular chatbots generating false misleading information...
#
# Story 236, et prime ever since ai became buzzword scramble use slew...
#
# Story 237, board voted friday send agreement studio member ratification process end...
#
# Story 238, generative ai already made huge impact technology used daily basis...
#
# Story 239, roaring success chatgpt triggered race among big tech company either...
#
# Story 240, clock tick toward tax filing deadline people desperate enough turn...
#
# Story 241, new delhi edtech platform move towards deploying artificial intelligence tool...
#
# Story 242, satya nadella tuesday talk serious business technology talk india born...
#
# Story 243, company new technology opportunity enhance productivity profit worker benefit well...
#
# Story 244, award announced president biden plant arizona biggest government made new...
#
# Story 245, amazon touchless technology allows customer grab need shelf walk without...
#
# Story 246, nearly year oren etzioni among optimistic artificial intelligence researcher etzioni...
#
# Story 247, despite computer shortage controversy lawsuit continues improve rapid pace anthropic...
#
# Story 248, new york time first report artificial intelligence according chatgpt july...
#
# Story 249, board voted friday send agreement studio member ratification process end...
#
# Story 250, google hosted annual google marketing live today may google bay...
#
# Story 251, explosive growth artificial intelligence ai augmenting capacity several sector concern...
#
# Story 252, general timothy haugh taking spy agency cyber command organization look...
#
# Story 253, fake photo explosion near pentagon went viral across twitter monday...
#
# Story 254, instagram facebook snapchat several newcomer betting artificial intelligence rejuvenate fun...
#
# Story 255, google new pixel let use artificial intelligence add remove element...
#
# Story 256, abstract greg ip capital account column suggests generative apps openai...
#
# Story 257, greenwashing much sleep debt unfamiliar term probably one recognized famous...
#
# Story 258, mumbai increasing number ceo cxos top management professional seeking upskill...
#
# Story 259, office overlooking taipei mountain surround taiwanese capital morris chang recently...
#
# Story 260, artificial intelligence tool conjure whimsical artwork image written command started...
#
# Story 261, raj ananthanpillai founder ceo trua identity verification screening company discus...
#
# Story 262, generative technology write poetry computer program create image teddy bear...
#
# Story 263, rap beef two dominant star left fan wondering whether new...
#
# Story 264, link image paris olympics set begin july professor computer science...
#
# Story 265, tech giant unbundling team office software suite face mounting scrutiny...
#
# Story 266, regulating ai tool economic time july saturday copyright bennett coleman...
#
# Story 267, version photoshop image generator midjourney live hype hello welcome back...
#
# Story 268, new delhi india plan establish principle act guardrail artificial intelligence...
#
# Story 269, shift indicative importance new artificial intelligence technology silicon valley wall...
#
# Story 270, new delhi multinational retail hypermarket walmart sourced billion good indian...
#
# Story 271, abstract need imaginative news leader bound model past full text...
#
# Story 272, digital landscape continues dynamic evolution realm advertising technology known adtech...
#
# Story 273, fashion ecommerce company myntra integrating generative ai chatbot chatgpt app...
#
# Story 274, decade easy get help repairing iphone cracked screen replaced minute...
#
# Story 275, company invested billion generative pioneer openai say giant system necessarily...
#
# Story 276, tech giant wrapping argument federal monopoly trial framed good corporate...
#
# Story 277, country global institution must work together harmonise effort tackle issue...
#
# Story 278, sundar pichai google chief executive testified tuesday second time two...
#
# Story 279, abstract airline using artificial intelligence save fuel keep customer informed...
#
# Story 280, dentons decision quit country new investment limit biden administration underscore...
#
# Story 281, called summer strike come time worker increasingly fear new technology...
#
# Story 282, imagine world deepfakes believably imitate voice politician used gin scandal...
#
# Story 283, idea networking make several professional groan small talk attending event...
#
# Story 284, washington prominent defense attorney whose star client included snoop dogg...
#
# Story 285, number republican lawmaker taken money company vilified party presidential hopeful...
#
# Story 286, transcribing physician note care provided patient billion business doctor voice...
#
# Story 287, independence day weekend saw crore gross collection record indian cinema...
#
# Story 288, bengaluru american chipmaker nvidia reliance industry india largest company market...
#
# Story 289, tool powered entirely artificial intelligence getting first test pennsylvania democrat...
#
# Story 290, former infosys president ravi kumar completes one year ceo service...
#
# Story 291, johnny taylor tackle human resource question part series usa today...
#
# Story 292, story syndicated substack newsletter big technology subscribe free ai program...
#
# Story 293, november ilya sutskever joined three openai board member force sam...
#
# Story 294, san francisco multinational semiconductor company advanced micro device amd artificial...
#
# Story 295, artificial intelligence argued online chatbot chatgpt substitute new york time...
#
# Story 296, katie drummond next top editor wired overseeing tech publication team...
#
# Story 297, new delhi india plan establish principle act guardrail artificial intelligence...
#
# Story 298, seems hollywood fight artificial intelligence ai long one streaming giant...
#
# Story 299, global software giant adobe tuesday announced beta launch new generative...
#
# Story 300, google parent company returned sale growth even advertising slowdown continued...
#
# Story 301, mumbai green shoot started showing service company catastrophic year tech...
#
# Story 302, large proportion user engaging ethically questionable activity work using generative...
#
# Story 303, openai associated press thursday made deal artificial intelligence company license...
#
# Story 304, tool chatgpt open new line question around tech product harmful...
#
# Story 305, december day set revolution across videogame industry appeared start innocuously...
#
# Story 306, master tournament sport unresolved fight pga tour liv golf loom...
#
# Story 307, bengaluru india key data centre focus semiconductor company advanced micro...
#
# Story 308, india dominant position global technology landscape traditionally fueled robust service...
#
# Story 309, haley joel osment eerie android child futuristic world smith battling...
#
# Story 310, smart treasury underwriting acumen access inexpensive deposit longer enough cement...
#
# Story 311, federal trade commission launched investigation chatgpt creator openai whether artificial...
#
# Story 312, air india talk aerospace major including airbus potential partner big...
#
# Story 313, year designer computer chip mainly used one tactic boost performance...
#
# Story 314, new york among group company working system produce short video...
#
# Story 315, google friday published whitepaper suggestion policy agenda responsible ai progress...
#
# Story 316, marisa shuman computer science class young woman leadership school bronx...
#
# Story 317, amazon box salesforce oracle others recently rolled product help workplace...
#
# Story 318, openai released new version image generator small group tester incorporated...
#
# Story 319, developer artificial intelligence system vehicle raised funding softbank nvidia microsoft...
#
# Story 320, nexus venture partner venture capital major led million funding round...
#
# Story 321, track heart sleeve went viral taken streaming service week may...
#
# Story 322, inbox management wondered robot five hour enough time watch mets...
#
# Story 323, international forum secretary state artificial intelligence ability disrupt global flow...
#
# Story 324, digital landscape continues dynamic evolution realm advertising technology known adtech...
#
# Story 325, retail scary business consumer spending cautiously luxury industry particular feeling...
#
# Story 326, people created image swift thought sort game researcher image taylor...
#
# Story 327, poll generated artificial intelligence embedded next guardian article microsoft news...
#
# Story 328, new delhi india plan establish principle act guardrail artificial intelligence...
#
# Story 329, zvolv company operation across india u mea anz raised million...
#
# Story 330, among many unique experience reporting young industry flooded hype money...
#
# Story 331, et host sam altman june mumbai sam altman openai chatgpt...
#
# Story 332, literary theory robot dennis yi tenen playful new book artificial...
#
# Story 333, worry interest rate grown since tuesday consumer price index report...
#
# Story 334, mobile app openai chatgpt downloaded million time globally since launch...
#
# Story 335, month old apps midjourney stable diffusion changing filmmaker interior designer...
#
# Story 336, effort large section u technology major subject generative ai curb...
#
# Story 337, past two decade word startup become synonymous india today startup...
#
# Story 338, called summer strike come time worker increasingly fear new technology...
#
# Story 339, five beverly hill expelled involvement creation sharing fake nude picture...
#
# Story 340, youtube rolling new rule ai content including requirement creator reveal...
#
# Story 341, publication minute last meeting u federal open market committee fomc...
#
# Story 342, many million job world including job europe risk replaced way...
#
# Story 343, de moines iowa cost building artificial intelligence product chatgpt hard...
#
# Story 344, american worried artificial intelligence technology chatgpt used worsen social ill...
#
# Story 345, abstract labor contract negotiation heat hollywood union representing writer actor...
#
# Story 346, every tuesday friday ezra klein invite conversation something matter today...
#
# Story 347, artificial intelligence affecting every industry retail mean increasingly personalized experience...
#
# Story 348, mira murati previously served chief technology officer named interim chief...
#
# Story 349, meta final phase rebuilding recommendation model part company tech roadmap...
#
# Story 350, newly inducted chief cognizant ravi kumar clear brief tasked reviving...
#
# Story 351, new delhi generative artificial intelligence ai tool may necessarily lead...
#
# Story 352, pi tool debuted week twist new wave chatbots assist people...
#
# Story 353, recent week american lawmaker moved ban app tiktok president biden...
#
# Story 354, generating slide deck talking point meeting minute done snap need...
#
# Story 355, pressure white house government around globe major technology company pledged...
#
# Story 356, next fiscal year expected better technology service current year tata...
#
# Story 357, chatbot called chatgpt hit internet late last year executive number...
#
# Story 358, crowded generative artificial intelligence race saw another rising star inflection...
#
# Story 359, elon musk involved legal tussle chatgpt maker openai artificial intelligence...
#
# Story 360, artificial intelligence transform economy today thought take break usual preoccupation...
#
# Story 361, settlement real estate industry case study central flaw economic theory...
#
# Story 362, bengaluru cognizant bagged active early client engagement focussed cognitive generative...
#
# Story 363, move come ruling international trade commission create run watch sale...
#
# Story 364, global content cloud software conglomerate adobe look integrate artificial intelligence...
#
# Story 365, fort lauderdale donald trump former campaign manager looked squarely camera...
#
# Story 366, year looking grim news business facing set harsh financial reality...
#
# Story 367, biggest threat tool manage cybersecurity generative ai microsoft usa vice...
#
# Story 368, matthew hitchcock family physician chattanooga helper record patient visit smartphone...
#
# Story 369, person decade ago five year even month ago likely answer...
#
# Story 370, past year saw explosion artificial intelligence chatbots meteoric rise openai...
#
# Story 371, shareholder set vote thursday whether back company incumbent board candidate...
#
# Story 372, mumbai pocket fm leading audio entertainment platform raised million funding...
#
# Story 373, even tried artificial intelligence tool write essay poem conjure new...
#
# Story 374, india market french service major capgemini solid base service client...
#
# Story 375, chatbots useful writing essay email designed show empathy retain memory...
#
# Story 376, world first news network entirely generated artificial intelligence set launch...
#
# Story 377, artificial intelligence new classical music recent rapid development composer worried...
#
# Story 378, sam altman dismissal rapid reinstatement chief executive openai creator chatgpt...
#
# Story 379, hidden inside foundation popular artificial intelligence image generator thousand image...
#
# Story 380, digital landscape continues dynamic evolution realm advertising technology known adtech...
#
# Story 381, draft law european parliament become world attempt address potentially harmful...
#
# Story 382, dark daiki funamizu pulled truck market osaka ending haul japan...
#
# Story 383, internal meeting chief executive explained plan artificial intelligence metaverse rebooting...
#
# Story 384, avatar addressing voter name whichever india many language speak expert...
#
# Story 385, avatar addressing voter name whichever india many language speak expert...
#
# Story 386, new delhi terming demand pause ai development uncalled senior vice...
#
# Story 387, abstract security chief say benefit artificial intelligence technology clear promise...
#
# Story 388, new technology upend many online business company figure work boon...
#
# Story 389, good starting point boost innovation new delhi bengaluru india ambitious...
#
# Story 390, instagram facebook snapchat several newcomer betting artificial intelligence rejuvenate fun...
#
# Story 391, hirings global capability centre global business service come positive news...
#
# Story 392, recent report goldman sachs economics research concludes super intelligent artificial...
#
# Story 393, artificial intelligence ai going augment human ingenuity replace shantanu narayen...
#
# Story 394, billionaire elon musk last thursday filed lawsuit chatgpt maker openai...
#
# Story 395, amazon began testing agility robotics walking bot bright blue autonomous...
#
# Story 396, bengaluru disprz corporate learning skilling platform raised million series funding...
#
# Story 397, percent licensed child care provider united state received grant used...
#
# Story 398, tentative agreement includes improvement wage guardrail around artificial intelligence union...
#
# Story 399, look patient visit technology put back room patient opposed putting...
#
# Story 400, austin texas elon musk formed new company focused artificial intelligence...
#
# Story 401, global technology major sap adobe ibm microsoft building cutting edge...
#
# Story 402, thanks strong capital market average annual total shareholder return surged...
#
# Story 403, internal disagreement direction apple car led effort sputter year canceled...
#
# Story 404, kapture cx customer support platform enterprise raised million india alternative...
#
# Story 405, link image wendy announced pilot program google cloud introduce artificial...
#
# Story 406, knew going bad time sat watch thing much internet already...
#
# Story 407, abstract baidu unveils new generative artificial intelligence model claim rival...
#
# Story 408, sale first republic bank official move contain banking crisis early...
#
# Story 409, ai replacing hand stock dealing room bank treasury assembly line...
#
# Story 410, many feared artificial intelligence kill job hospital insurance company others...
#
# Story 411, alexa speak dubliner amazon researcher crack problem vexed data scientist...
#
# Story 412, mumbai pocket fm leading audio entertainment platform raised million funding...
#
# Story 413, general timothy haugh taking spy agency cyber command organization look...
#
# Story 414, software developer across organisation taking generative artificial intelligence ai tool...
#
# Story 415, second story book post read first post amidst denial computer...
#
# Story 416, great resignation wave tech layoff people interested freelance work freelancing...
#
# Story 417, partnership extend long relationship company helped deliver everything map search...
#
# Story 418, recently downloaded virtual assistant promised ease burden modern parenthood app...
#
# Story 419, summary summary summary editor pose extinction tech leader warn front...
#
# Story 420, adding zomato india portfolio month ago jefferies christopher wood gone...
#
# Story 421, abstract julie jargon personal journal column note tessa chatbot veered...
#
# Story 422, news medium alliance trade group represents newspaper say chatbots use...
#
# Story 423, archbishop mansion san francisco built stately hotel northeast corner alamo...
#
# Story 424, et explainer new delhi billionaire elon musk last thursday filed...
#
# Story 425, amid widespread weakness technology stock worldwide american cybersecurity provider palo...
#
# Story 426, listen follow hard fork apple spotify stitcher amazon google sit...
#
# Story 427, hiking interest rate aggressively federal reserve done past month fight...
#
# Story 428, experimented chatbots tool discovered played generative artificial intelligence chatgpt text...
#
# Story 429, comply european regulation apple proposed reducing commission app sale adding...
#
# Story 430, virtual assistant decade become indispensable hampered clunky design miscalculation leaving...
#
# Story 431, google wednesday began unveiling artificial intelligence ai product answer latest...
#
# Story 432, conversation unhinged bing made rethink give human moral value essay...
#
# Story 433, alex popken longtime trust safety executive twitter focusing content moderation...
#
# Story 434, google ceo sundar pichai national security consideration ai advocated exercising...
#
# Story 435, wendy menu board ben amp jerry grocery store freezer abercrombie...
#
# Story 436, president joe biden signed artificial intelligence executive order monday marking...
#
# Story 437, generative artificial intelligence ai platform openai loss nearly doubled million...
#
# Story 438, mukesh reliance industry tied chipmaker nvidia develop india foundation large...
#
# Story 439, masala papdi chatgpt generative ai grabbed attention academic industry policymakers...
#
# Story 440, china tech firm caught guard breakthrough generative artificial intelligence beijing...
#
# Story 441, technology service consulting company wipro tuesday announced expanded partnership google...
#
# Story 442, plan meal find gift create story using generative hello back...
#
# Story 443, openai company created chatgpt started race among tech company large...
#
# Story 444, washington president joe biden campaign democratic candidate fevered race republican...
#
# Story 445, internet giant grant user access chatbot year cautious development chasing...
#
# Story 446, new york among group company working system produce short video...
#
# Story 447, mumbai air india talk aerospace major including airbus potential partner...
#
# Story 448, india play key role building resilient global electronics supply chain...
#
# Story 449, abstract new class cyberattacks becoming important technology company insert new...
#
# Story 450, heading tomorrow next year beyond today newsletter last series look...
#
# Story 451, san francisco multinational semiconductor company advanced micro device amd artificial...
#
# Story 452, important economic data delayed regulator decision merger new public listing...
#
# Story 453, bengaluru generative artificial intelligence ai solution provider ema raised million...
#
# Story 454, company created chatgpt thrown turmoil monday microsoft hired ousted ceo...
#
# Story 455, admit never great coming gift idea gift speak knowing exactly...
#
# Story 456, even india largest stock trading peak level bargain hunter obsessed...
#
# Story 457, indian share rose monday gain private lender icici bank quarterly...
#
# Story 458, premium people tell thing know grow importance machine say jim...
#
# Story 459, amazon touchless technology allows customer grab need shelf walk without...
#
# Story 460, first glide horizon world virtual reality app meta platform greeted...
#
# Story 461, republican national committee fired attack ad soon president joe biden...
#
# Story 462, recent week american lawmaker moved ban app tiktok president biden...
#
# Story 463, little hard believe year ago group leading researcher asked pause...
#
# Story 464, bengaluru amazon web service aws india private ltd expanded cloud...
#
# Story 465, expectation never great exceed performance parameter consummate ease much relative...
#
# Story 466, image generated lensa ai social medium cost noticed many friend...
#
# Story 467, handful moment century experienced huge shift skill economy value entering...
#
# Story 468, use content news information provider train artificial intelligence system may...
#
# Story 469, london executive feeling better global economy growing number think company...
#
# Story 470, tech industry year transformation spurred success last year breakout tech...
#
# Story 471, regulator opened inquiry board unexpectedly fired company chief executive sam...
#
# Story 472, draft law european parliament become world attempt address potentially harmful...
#
# Story 473, adoption generative artificial intelligence customer engagement picking pace instance conversational...
#
# Story 474, disprz corporate learning skilling platform raised million series funding round...
#
# Story 475, abstract author artist internet publisher seeking compensation use work train...
#
# Story 476, wpp world biggest advertising group open acquiring company india allow...
#
# Story 477, new database company mongodb see great opportunity india large bank...
#
# Story 478, late openai faced supply problem artificial intelligence lab exhausted every...
#
# Story 479, company discussed multiyear deal worth least million train generative system...
#
# Story 480, company edge blocking creation distribution child sexual abuse material seen...
#
# Story 481, microsoft invest billion emirati company tie china washington beijing maneuver...
#
# Story 482, gov josh shapiro administration use artificial intelligence pilot program help...
#
# Story 483, potential deal bolster streaming business negotiating power cable operator crushing...
#
# Story 484, amid news openai possibly leaving europe due regulator tightening noose...
#
# Story 485, chinese company inc unit jd cloud launch product similar chatgpt...
#
# Story 486, mumbai india inc need reskill employee improve efficiency seek keep...
#
# Story 487, new delhi taiwanese chipmaker mediatek gunning premium segment coming year...
#
# Story 488, many site get least half traffic search engine fuller result...
#
# Story 489, technology amazon cutting jobstied alexa product amazon trimming job alexa...
#
# Story 490, mumbai green shoot started showing service company catastrophic year tech...
#
# Story 491, president effort court voter crucial swing state influencing economic trade...
#
# Story 492, generative artificial video creation platform tuesday raised million seed funding...
#
# Story 493, bengaluru amazon web service aws india private ltd expanded cloud...
#
# Story 494, move test european union new tech competition law designed allow...
#
# Story 495, agrees new york time june saturday est copyright new york...
#
# Story 496, google took next leap artificial intelligence wednesday launch project gemini...
#
# Story 497, abstract startup pouring money generative technology underlying application openai chatgpt...
#
# Story 498, dozen company popped offer service aimed identifying whether photo text...
#
# Story 499, abstract james mackenzie letter responds peggy noonan april declaration column...
#
# Story 500, new delhi transformation telecommunication company india around world tech company...

# %% [markdown]
# ### Construct the Variables

# %%
import pandas as pd
import re

def count_occurrences(text, phrase):
    # Count occurrences of the phrase in the text (case insensitive)
    return len(re.findall(f'\\b{phrase}\\b', text, flags=re.IGNORECASE))

def variable_construct(input_file_path, output_file_path, phrases):
    # Read original CSV file
    df = pd.read_csv(input_file_path)
    
    # Initialize empty lists to store counts
    counts_risk = []
    counts_privacy = []
    counts_job = []
    counts_wage  = []
    
    # Process each Body_text to count occurrences of the phrases
    for body_text in df['Body_text']:
        count_risk = count_occurrences(body_text, phrases['risk'])
        count_privacy = count_occurrences(body_text, phrases['privacy'])
        count_job = count_occurrences(body_text, phrases['job'])
        count_wage = count_occurrences(body_text, phrases['wage'])
        
        counts_risk.append(count_risk)
        counts_privacy.append(count_privacy)
        counts_job.append(count_job)
        counts_wage.append(count_wage)
    
    # Add new columns to DataFrame
    df['risk'] = counts_risk
    df['privacy'] = counts_privacy
    df['job'] = counts_job
    df['wage'] = count_wage
    
    # Drop 'Body_text' column from DataFrame
    df.drop(columns=['Body_text'], inplace=True)
    
    # Save DataFrame to new CSV file
    df.to_csv(output_file_path, index=False)

# Example usage
input_file_path  = 'df_construct_300.csv'
output_file_path = 'df_variables_300.csv'

# Define phrases to count
phrases = {
    'risk': 'risk',
    'privacy': 'privacy',
    'job': 'job',
    'wage': 'wage'
}

variable_construct(input_file_path, output_file_path, phrases)
