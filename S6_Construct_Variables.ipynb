# %% [markdown]
# ### Construct DataFrame

# %%
import pandas as pd
import json

def dataframe_construct(input_file_path, output_file_path):
    # Read JSON file
    with open(input_file_path, 'r', encoding='utf-8') as file:
        # Load JSON data
        data = json.load(file)
        
    # Initialize lists to store story_id and body_text
    story_ids = []
    body_texts = []

    # Process each story in the JSON data
    for idx, story in enumerate(data):
        # Extract story_id and body_text
        story_id = idx + 1  # Assuming story_id starts from 1
        body_text = story.strip('"')  # Remove leading/trailing quotes
        
        # Append to lists
        story_ids.append(story_id)
        body_texts.append(body_text)

    # Create DataFrame
    df = pd.DataFrame({'Story_ID': story_ids, 'Body_text': body_texts})

    # Save DataFrame to CSV with headers and without index column
    df.to_csv(output_file_path, index=False, header=True)
    
    # Read CSV file
    df_csv = pd.read_csv(output_file_path)

    # Print first 10 words of each body_text
    print("Printing first 10 words of each story:")
    for index, row in df_csv.iterrows():
        first_10_words = ' '.join(row['Body_text'].split()[:10])
        print(f"Story {row['Story_ID']}, {first_10_words}...")
        print()  # Separate each story

# Example usage
input_file_path = 'tokenizedBERT_500.json'
output_file_path = 'df_construct_500.csv'
dataframe_construct(input_file_path, output_file_path)
# Out:
# Printing first 10 words of each story:
# Story 1, info ink large deal new economic time paper edition june...
#
# Story 2, tin chat worker wonder take job new york time march...
#
# Story 3, growth competitive pay top priority gen stay job economic time...
#
# Story 4, chat con big tech promise per new york time march...
#
# Story 5, u tech stock time book profit economic time paper edition...
#
# Story 6, transcript ezra klein interview ethan mo ezra klein show new...
#
# Story 7, inside baltimore sun november tuesday first edition copyright baltimore sun...
#
# Story 8, ground bid anti agenda deal newsletter new york time february...
#
# Story 9, preventing voter di crisis ai turbo di especially community color...
#
# Story 10, new feeding habit ai economic time paper edition february saturday...
#
# Story 11, microsoft seek dismiss part lawsuit brought new york time new...
#
# Story 12, homework out new york time january tuesday late edition final...
#
# Story 13, cap technology extends latest funding round raise million secondary economic...
#
# Story 14, use ai plan next vacation know first usa today online...
#
# Story 15, time sue open microsoft use copyright work new york time...
#
# Story 16, worker promise threat new york time march wednesday late edition...
#
# Story 17, degree artificial intelligence penn becomes first ivy offer ai major...
#
# Story 18, revolution coming fast people think new york time august tuesday...
#
# Story 19, photo get easy maybe easy far man new york time...
#
# Story 20, address artificial intelligence workplace usa today march tuesday edition copyright...
#
# Story 21, used grammar proof paper accused un cheating usa today online...
#
# Story 22, google roll genus ai chat bard country including india economic...
#
# Story 23, amazon product launch echo alexa connected smart home may soon...
#
# Story 24, first sean toy ou board real image created ai fact...
#
# Story 25, department homeland security embracing new york time march monday est...
#
# Story 26, google testing tool write news article new york time july...
#
# Story 27, excessive focus regulation ham india ai potential economic time paper...
#
# Story 28, deep tech vc india focus genus ai re tech economic...
#
# Story 29, apple google discussing deal bring genus iphone new york time...
#
# Story 30, open deal put value billion new york time february monday...
#
# Story 31, business quickly find us tech company rush offer product new...
#
# Story 32, chevrolet dealer offered ai chat website told customer buy ford...
#
# Story 33, pope beer burning man francis became favored muse artist new...
#
# Story 34, company swamp artificial intelligence tool wall street journal abstract july...
#
# Story 35, digest new york time july wednesday late edition final copyright...
#
# Story 36, silicon valley venture capital meet generation shift new york time...
#
# Story 37, et explain google microsoft log uk economic time december tuesday...
#
# Story 38, one way help journalism industry crisis make school free guest...
#
# Story 39, geek squad among laid best buy worker ai help usa...
#
# Story 40, sen sc proposes framework ai regulation aim address potential risk...
#
# Story 41, berkshire leader take bank ai wall street journal abstract may...
#
# Story 42, zu lay road map meta new york time june friday...
#
# Story 43, google test tool able write news article new york time...
#
# Story 44, skill platform di bag lu others economic time paper edition...
#
# Story 45, putting ai job boost productivity profit wall street journal abstract...
#
# Story 46, liable creation deal newsletter new york time june saturday est...
#
# Story 47, big buzz da ukraine china middle east deal newsletter new...
#
# Story 48, open ceo sam alt visit japan government embrace chat new...
#
# Story 49, leap forward may occur new york time january tuesday late...
#
# Story 50, artist residence territory new york time december saturday est copyright...
#
# Story 51, ai reflects demon angel nature wall street journal abstract april...
#
# Story 52, ai change quality accessibility digital education economic time paper edition...
#
# Story 53, ai take world stay relevant begin replacing job ask hr...
#
# Story 54, ag dh pilot seed new ai revolution economic time january...
#
# Story 55, big tech rival put chip table new york time january...
#
# Story 56, deep ai take centre stage second day startup maha economic...
#
# Story 57, ai global issue need global approach govern economic time paper...
#
# Story 58, amazon take big stake start ant new york time september...
#
# Story 59, india compute infrastructure deficit hind ai potential executive economic time...
#
# Story 60, gen set move value project go live tc ct ha...
#
# Story 61, meta long leader try left boom new york time february...
#
# Story 62, doctoral programme economic time paper edition april monday delhi edition...
#
# Story 63, genus ai firm building capability unprecedented way economic time may...
#
# Story 64, fake rob doctor video facebook urged fix election problem usa...
#
# Story 65, tech company sign accord combat ai generated election trick major...
#
# Story 66, apple explores deal news publisher new york time december friday...
#
# Story 67, apple spot creator feeling flat new york time may friday...
#
# Story 68, pope francis star generated photo new york time april saturday...
#
# Story 69, et explain indian company concerned accent guidance economic time december...
#
# Story 70, publisher gi threat new york time march friday late edition...
#
# Story 71, net economic time paper edition april friday mumbai edition copyright...
#
# Story 72, chief worried deal newsletter new york time august monday est...
#
# Story 73, student saying learning write age current event conversation new york...
#
# Story 74, next fear hollywood killer robot become military tool news analysis...
#
# Story 75, business give upbeat forecast ai hit tipping point chip say...
#
# Story 76, college say ai used positively classroom artificial intelligence help student...
#
# Story 77, artist push ai copyright reform tech industry resist baltimore sun...
#
# Story 78, meta roll smart assistant across apps new york time april...
#
# Story 79, open say new york time lawsuit without merit new york...
#
# Story 80, samsung galaxy launch watch un event life economic time january...
#
# Story 81, ai change workplace auto idea wall street journal abstract may...
#
# Story 82, ai video generator dream san pedro madonna among early adopt...
#
# Story 83, high school story recent new york time reporting secondary schooling...
#
# Story 84, google plan chat response chat new york time february tuesday...
#
# Story 85, quota day out health care paperwork new york time june...
#
# Story 86, homeland security embracing plan use tool across agency new york...
#
# Story 87, robot learned write well nonfiction new york time february wednesday...
#
# Story 88, explicit deep image taylor swift el safeguard swamp social medium...
#
# Story 89, google chrome user access microsoft ai powered bing chat desktop...
#
# Story 90, air india tap airbus training unit economic time paper edition...
#
# Story 91, impact search engine economic time paper edition july monday mumbai...
#
# Story 92, deep ai take centre stage second day startup maha economic...
#
# Story 93, tin chat worker wonder take job new york time international...
#
# Story 94, america china crisis trust thomas friedman new york time international...
#
# Story 95, accent spot revenue ups via gen economic time february monday...
#
# Story 96, google brings bard chat india user economic time paper edition...
#
# Story 97, ant chat rival founded daniela dario worth billion new york...
#
# Story 98, ti meta address online hate pittsburgh summit pittsburgh post gazette...
#
# Story 99, price bit mining week reporter read new york time april...
#
# Story 100, sarah silver novelist sue chat maker open ing book dayton...
#
# Story 101, expert ai bad duke law professor say artificial intelligence lead...
#
# Story 102, ai replace full time tech role annually expert economic time...
#
# Story 103, ed ai push share doubt thomas economic time paper edition...
#
# Story 104, sp hope gloom medium landscape new york time march tuesday...
#
# Story 105, allegheny general hospital nurse weigh day walk notice vote set...
#
# Story 106, sp hope gloom medium landscape new york time international edition...
#
# Story 107, china ai model give silicon valley run money economic time...
#
# Story 108, actor vote author strike writer continue picket new york time...
#
# Story 109, india rich tech talent pool big win win economic time...
#
# Story 110, writer used ai pl new york observer january tuesday copyright...
#
# Story 111, richard rodgers chat well quite new york time november thursday...
#
# Story 112, identity theft take massive toll victim life may even lead...
#
# Story 113, sport league bet gambling facing risk deal newsletter new york...
#
# Story 114, excel making bad art artist teach create something good new...
#
# Story 115, chip maker catch ai wave wall street journal abstract march...
#
# Story 116, nt sell controlling stake pune based ni promoter economic time...
#
# Story 117, blessing boo ad warily embrace new york time july tuesday...
#
# Story 118, startup ecosystem today remarkably different compared year ago sank ata...
#
# Story 119, voice deep coming bank balance new york time international edition...
#
# Story 120, hello bard google open public access chat rival economic time...
#
# Story 121, genus ai re workforce company may affected wall street journal...
#
# Story 122, cm al role robotic solution humanoid bot tested amazon warehouse...
#
# Story 123, ti test ai chat wall street journal abstract may friday...
#
# Story 124, ai yet make big impact marketing economic time paper edition...
#
# Story 125, hurdle filled race make computer chip new york time may...
#
# Story 126, drone delivery new ai tech guide wal unveiled ce usa...
#
# Story 127, good tech award went right new york time december friday...
#
# Story 128, ibm try as customer genus safe bet new york time...
#
# Story 129, key open executive played pivotal role sam alt ou new...
#
# Story 130, school survive maybe even thrive fall shift new york time...
#
# Story 131, m gi indian developer pip u economic time paper edition...
#
# Story 132, meet co racing open global marathon economic time paper edition...
#
# Story 133, market expect fed raise rate despite banking turmoil deal newsletter...
#
# Story 134, amazon new chat shop new york time february friday late...
#
# Story 135, sa slash startup enterprise value forecast economic time july friday...
#
# Story 136, apple fined billion using app store th competition new york...
#
# Story 137, sale ceo marc ben ai none u ready new york...
#
# Story 138, together un new fund worth million back opportunity gen ai...
#
# Story 139, former trump fix michael cohen acknowledges submit ai generated fake...
#
# Story 140, apple laid employee car smart screen project shut shop report...
#
# Story 141, co ai officially launch partnership google cloud economic time december...
#
# Story 142, activist investor scott murray urge get image enter ai partnership...
#
# Story 143, teacher student feel new york time august thursday est copyright...
#
# Story 144, ref ana algorithm amazon new york observer july thursday copyright...
#
# Story 145, bold volunteer frontier hears future new york time may thursday...
#
# Story 146, powered search engine replace google shift new york time international...
#
# Story 147, publisher worry chat cut reader new york time march thursday...
#
# Story 148, ai generated music shaking industry economic time april sunday copyright...
#
# Story 149, future education luca ai us chat teach reading skill child...
#
# Story 150, stock market today asian share weaken japan report economy grew...
#
# Story 151, may someday work medical miracle help paperwork new york time...
#
# Story 152, int look human rein ai wall street journal abstract october...
#
# Story 153, text message new social medium one start think deal newsletter...
#
# Story 154, lay guide genus ai baltimore sun january wednesday first edition...
#
# Story 155, ai replace full time tech role annually expert economic time...
#
# Story 156, airline airport gather robotics summit pittsburgh post gazette may thursday...
#
# Story 157, fe move toward potentially regulating ai deep campaign ad federal...
#
# Story 158, google may invest indian ai company co ai economic time...
#
# Story 159, el mu plan ai startup compete open chat report economic...
#
# Story 160, taking note learning new york time september sunday late edition...
#
# Story 161, school cope grow student using new york time august tuesday...
#
# Story 162, artificial intelligence evolve screenwriter actor see threat new york time...
#
# Story 163, pre crime fighting key tech economic time paper edition november...
#
# Story 164, end begin turning point guest essay new york time december...
#
# Story 165, congress move new rule online child safety deal newsletter new...
#
# Story 166, regulator force another microsoft split deal newsletter new york time...
#
# Story 167, microsoft incorporates genus ai tool business software wall street journal...
#
# Story 168, coming party genus silicon valley new cr shift new york...
#
# Story 169, hollywood labor tu director stand apart new york time july...
#
# Story 170, google test assistant offer life advice new york time august...
#
# Story 171, audio platform pocket fm make u entry exceeds million ar...
#
# Story 172, chat write next succession new york time april saturday est...
#
# Story 173, sale walk fine line ai push wall street journal abstract...
#
# Story 174, excerpt podcast ai unleashed concerned usa today online january copyright...
#
# Story 175, china new chat say asked taiwan new york time july...
#
# Story 176, word screen ai economic time paper edition april sunday kolkata...
#
# Story 177, robot pouring drink server striking new york time october sunday...
#
# Story 178, wednesday briefing aid worker killed gaza new york time april...
#
# Story 179, transcript ezra klein interview al nelson ezra klein show new...
#
# Story 180, tv ad made screen new york time june tuesday est...
#
# Story 181, apple reverse course allows epic game start competing app store...
#
# Story 182, ai change workplace productivity boost wall street journal abstract may...
#
# Story 183, industry insider drive open alternative big tech new york time...
#
# Story 184, google take another turn anti witness stand new york time...
#
# Story 185, daily money american purchasing power recover wage growth inflation usa...
#
# Story 186, return magician ross new york time march thursday est copyright...
#
# Story 187, ai may revolution email hacker wall street journal abstract september...
#
# Story 188, revolution coming hard say new york time september monday late...
#
# Story 189, microsoft make new push smaller system new york time april...
#
# Story 190, investor flock hear buffet bet next new york time may...
#
# Story 191, class teacher new york time september thursday late edition final...
#
# Story 192, hollywood actor union board approve strike ending deal leader money...
#
# Story 193, spend billion ai wall street journal abstract april thursday copyright...
#
# Story 194, open ceo set testify congress pittsburgh post gazette may thursday...
#
# Story 195, see vol near term chandra economic time paper edition june...
#
# Story 196, amid recent backlash effort grow diversity company go quiet new...
#
# Story 197, age tech workforce hiring lay economic time august wednesday copyright...
#
# Story 198, artificial intelligence gloss neural network term explained new york time...
#
# Story 199, apple new ipad ad leaf creative audience feeling flat new...
#
# Story 200, fake image swift hit social medium spread new york time...
#
# Story 201, sundance film festival guarding fest legacy future eugene hernandez fifth...
#
# Story 202, discussion chip fabrication scaling manufacturing investment economic time paper edition...
#
# Story 203, spurred teen girl state move ban deep nude new york...
#
# Story 204, info ceo pay fall cr economic time paper edition june...
#
# Story 205, chat sent work new york time february monday late edition...
#
# Story 206, norman za california modernist eye sky critic pick new york...
#
# Story 207, microsoft make high stake play tech cold war emir deal...
#
# Story 208, financial service company india best market tech talent morgan stanley...
#
# Story 209, senator ask package limit tech new york time may thursday...
#
# Story 210, chat sometimes make thing ai hall problem fix spend enough...
#
# Story 211, discussion chip fabrication scaling manufacturing investment economic time paper edition...
#
# Story 212, shield urged worker hurt new york time may wednesday late...
#
# Story 213, ai shaping future pittsburgh iconic manufacturer pittsburgh post gazette september...
#
# Story 214, alt control open regain seat board new york time march...
#
# Story 215, meta biggest push place smart assistant across apps new york...
#
# Story 216, skeptical ai healthcare doctor hospital using usa today online january...
#
# Story 217, et smart talk pr approach divide portfolio two part core...
#
# Story 218, data set billion deal ai startup wall street journal abstract...
#
# Story 219, roi silicon valley microsoft google find use daily tool new...
#
# Story 220, google cut free website cite low engagement thousand pa small...
#
# Story 221, ai global issue need global approach govern open jason kw...
#
# Story 222, open talk deal value company billion new york time october...
#
# Story 223, open investor vin spa el mu lawsuit economic time march...
#
# Story 224, sue apple accusing maintaining iphone monopoly new york time march...
#
# Story 225, bill ny doom clock scientist call action new york observer...
#
# Story 226, chinese chat must toe party line new york time april...
#
# Story 227, ibm try ease customer qu using genus new york time...
#
# Story 228, google amazon microsoft meta tech firm agree ai safeguard set...
#
# Story 229, owns song created deal newsletter new york time april saturday...
#
# Story 230, protection impact global gdp say mc company bob stern economic...
#
# Story 231, tc deal win spark relief rally stock economic time paper...
#
# Story 232, opt guide artificial intelligence work deal newsletter new york time...
#
# Story 233, take money advice new york time may saturday late edition...
#
# Story 234, company use sr higher chance winning tender responsive ceo economic...
#
# Story 235, business election threat chat inaccurate misleading response testing major ai...
#
# Story 236, chip rest economic time paper edition november sunday kolkata edition...
#
# Story 237, hollywood actor start voting tuesday contract deal new york time...
#
# Story 238, genus ai replace million job goldman sachs report economic time...
#
# Story 239, chat face competition four startup big tech radar new york...
#
# Story 240, ai flag tax mistake heavy lifting usa today march tuesday...
#
# Story 241, ed ai push share doubt thomas economic time paper edition...
#
# Story 242, va pa v pu nad ev chat settle spicy score...
#
# Story 243, biggest impact seen top industry new york time february friday...
#
# Story 244, intel receives billion grant build chip plant new york time...
#
# Story 245, amazon cash walk technology rely worker india usa today online...
#
# Story 246, researcher take election deep new york time april tuesday est...
#
# Story 247, start ant challenge open google new chat new york time...
#
# Story 248, chat hall new york time may monday est copyright new...
#
# Story 249, union board back contract go actor vote new york time...
#
# Story 250, google advertising exhibition new york observer may wednesday copyright new...
#
# Story 251, new ai disruption tool devin devil software engineer economic time...
#
# Story 252, install new director prepares election influence operation new york time...
#
# Story 253, pentagon pic demonstrates mi era baltimore sun may thursday first...
#
# Story 254, bring social back social network apps try imagery new york...
#
# Story 255, pixel based editing cross line new york time october thursday...
#
# Story 256, robot finally come job wall street journal abstract april thursday...
#
# Story 257, ne baby cr capitalism blur new word added dictionary com...
#
# Story 258, india inc heavyweight look ai drive innovation efficiency economic time...
#
# Story 259, chip titan whose life work center tech cold war new...
#
# Story 260, tech company try take ai image generator mainstream better protection...
#
# Story 261, risk sharing personal information baltimore sun november sunday advance edition...
#
# Story 262, new technology generates blue edit human dna new york time...
#
# Story 263, drake v kendrick lamar spoil new york time may thursday...
#
# Story 264, scientist say ai emerging potential tool aid athlete beat drug...
#
# Story 265, microsoft un team ahead regulator new york time april wednesday...
#
# Story 266, key nation international governing body regulating ai tool economic time...
#
# Story 267, use edit generate stunning photo new york time june friday...
#
# Story 268, india establish guard artificial intelligence economic time paper edition may...
#
# Story 269, microsoft top apple become valuable public company new york time...
#
# Story 270, wal look tre sour good india year economic time paper...
#
# Story 271, one way help journalism industry crisis make school free guest...
#
# Story 272, shaping india digital landscape economic time paper edition january friday...
#
# Story 273, integrate chat search better product discovery economic time may thursday...
#
# Story 274, paid iphone apple still control new york time november sunday...
#
# Story 275, microsoft make new push smaller system new york time international...
#
# Story 276, google argued defend landmark anti trial new york time november...
#
# Story 277, et gb ai global issue need global approach govern say...
#
# Story 278, google head run gan testify coast new york time november...
#
# Story 279, make connecting flight may thank new york time international edition...
#
# Story 280, lesson law firm decision leave china deal newsletter new york...
#
# Story 281, tech fear showing picket line deal newsletter new york time...
#
# Story 282, coming past new york time january tuesday late edition final...
#
# Story 283, peer treasure economic time paper edition october wednesday delhi edition...
#
# Story 284, pr michel former attorney plead guilty leaking information fu rapper...
#
# Story 285, republican bash get complicated deal newsletter new york time february...
#
# Story 286, ai helping doctor transcription pittsburgh post gazette november friday sooner...
#
# Story 287, ai actor det superstar economic time paper edition september saturday...
#
# Story 288, plan build super economic time paper edition september saturday delhi...
#
# Story 289, congressional candidate voter outreach tool latest ai experiment ahead election...
#
# Story 290, co get mojo back new ceo watch economic time january...
#
# Story 291, remain relevant ai develops usa today august wednesday edition copyright...
#
# Story 292, ai ethic war make content mode debate look picnic new...
#
# Story 293, open chief scientist co founder leaving company new york time...
#
# Story 294, global ai season su see big opening data centre economic...
#
# Story 295, open seek dismiss part new york time lawsuit new york...
#
# Story 296, wired name new top editor former intern senior executive vice...
#
# Story 297, india establish guard ai sector raj chandra economic time paper...
#
# Story 298, netflix post ai job listing hollywood actor writer continue strike...
#
# Story 299, adobe launch genus ai model fire economic time march thursday...
#
# Story 300, alphabet shrug advertising slump thanks search engine new york time...
#
# Story 301, dry spell sight green shoot higher budget economic time paper...
#
# Story 302, user pas gen ai work sale survey economic time december...
#
# Story 303, chat maker open sign deal ap license news story dayton...
#
# Story 304, new question liability artificial intelligence creation new york time june...
#
# Story 305, microsoft union friendly tech titan new york time february sunday...
#
# Story 306, golf big deal course deal newsletter new york time april...
#
# Story 307, workforce based india top ex economic time paper edition july...
#
# Story 308, lie ahead ni shifting landscape economic time january saturday copyright...
#
# Story 309, sa aft worried ai really replace actor already usa today...
#
# Story 310, big bank take large language model trained internal data economic...
#
# Story 311, ft investigating chat creator open consumer protection issue dayton daily...
#
# Story 312, air india tap airbus training unit economic time november monday...
#
# Story 313, focus chip stay cutting edge tech new york time may...
#
# Story 314, next big leap tech instant video command new york time...
#
# Story 315, ai important regulated say google economic time may saturday copyright...
#
# Story 316, new coding class cr chat new york time february monday...
#
# Story 317, business cl workplace tech company rush provide new york time...
#
# Story 318, chat generate image new york time september wednesday est copyright...
#
# Story 319, way start autonomous vehicle raise billion new york time may...
#
# Story 320, nexus venture partner lead million funding dev startup economic time...
#
# Story 321, hit fake drake week rattle music world new york time...
#
# Story 322, turning office new york time may sunday late edition final...
#
# Story 323, blink warns di threat demo new york time march monday...
#
# Story 324, shaping india digital landscape economic time paper edition january friday...
#
# Story 325, em retail founder ceo think beyond survival mode new york...
#
# Story 326, fake explicit image taylor swift started study say new york...
#
# Story 327, microsoft blasted poll placed near guardian article new york time...
#
# Story 328, india establish guard ai sector economic time paper edition may...
#
# Story 329, hyper platform secure million funding silver venture economic time february...
#
# Story 330, surprising thing engineer tell let ezra klein new york time...
#
# Story 331, view indian startup economic time paper edition june monday kolkata...
#
# Story 332, human intelligence brought ai nonfiction review baltimore sun february sunday...
#
# Story 333, prospect soft landing deal newsletter new york time february wednesday...
#
# Story 334, sam alt reveals used app chat bill gate podcast new...
#
# Story 335, generated art already transforming creative work shift new york time...
#
# Story 336, big lobbying der open source gen deep ai andrew ng...
#
# Story 337, india rich tech talent pool big win win economic time...
#
# Story 338, strike across industry worker fear new technology cost job new...
#
# Story 339, city state student expelled fake nude image five beverly vista...
#
# Story 340, youtube ask creator tell video ai baltimore sun november wednesday...
#
# Story 341, diversified genus ai key future growth say hc vijay economic...
#
# Story 342, two third job risk goldman sachs study new york observer...
#
# Story 343, thirsty ai technology behind chat iowa town water consumption spike...
#
# Story 344, many worry created monster survey ai concern range spreading lie...
#
# Story 345, chat write next succession new york time international edition may...
#
# Story 346, transcript ezra klein interview casey newton kevin ro ezra klein...
#
# Story 347, google crew ex discus online shopping age new york observer...
#
# Story 348, alt open board say blog post new york time november...
#
# Story 349, head facebook tom alison share update meta road new york...
#
# Story 350, big bang rational cost rein co ceo ravi kumar economic...
#
# Story 351, gen ai may lead job loss shift demand curve say...
#
# Story 352, emotional support chat new york time may thursday late edition...
#
# Story 353, leader lobby congress china tension rise new york time march...
#
# Story 354, use auto dread office meeting new york time june friday...
#
# Story 355, tech giant pledge crack election ai deep keep promise usa...
#
# Story 356, tech demand better fiscal tc ng sub economic time january...
#
# Story 357, microsoft bet big creator chat race dominate new york time...
#
# Story 358, bill gate eric schmidt pour cash ai startup new york...
#
# Story 359, el mu say ai smarter human next year economic time...
#
# Story 360, transform economy paul new york time october tuesday est copyright...
#
# Story 361, real big defeat new york time march monday est copyright...
#
# Story 362, co clock gen ai engagement economic time paper edition august...
#
# Story 363, apple pause selling new version watch losing patent dispute new...
#
# Story 364, adobe look integrate ai mi product india md economic time...
#
# Story 365, ex trump official tech digital campaign operative back advocate ai...
#
# Story 366, finding sp hope gloom medium era new york time march...
#
# Story 367, genus ai biggest weapon tool cyber microsoft brad smith economic...
#
# Story 368, may someday work medical miracle help paperwork new york time...
#
# Story 369, actually take step change personality trait baltimore sun august sunday...
#
# Story 370, year people behind hottest chat new york observer december thursday...
#
# Story 371, carl ic battle ill come head deal newsletter new york...
#
# Story 372, pocket fm net series raise light others economic time paper...
#
# Story 373, brand embracing use ai various way despite risk baltimore sun...
#
# Story 374, people come india talent cut cost cap global ceo aim...
#
# Story 375, ai developing multiple personality baltimore sun july thursday first edition...
#
# Story 376, none anchor real channel plan ai generate news broadcaster usa...
#
# Story 377, roll beethoven new york time june sunday late edition final...
#
# Story 378, open drama mark scary new era leadership shuffle mysterious effect...
#
# Story 379, explicit child photo hidden inside ai image generator los angeles...
#
# Story 380, shaping india digital landscape economic time paper edition january friday...
#
# Story 381, european take major step toward regulating new york time june...
#
# Story 382, truck crisis japan new york time december tuesday late edition...
#
# Story 383, rocky year zu lay meta road map employee new york...
#
# Story 384, tool change india election new york time april thursday new...
#
# Story 385, deep video change india election new york time april friday...
#
# Story 386, india priority mk google excited tech innovation economic time paper...
#
# Story 387, security chief reward risk genus ai inflated wall street journal...
#
# Story 388, chat internet industry ti new york time march wednesday est...
#
# Story 389, unlock funding economic time paper edition march saturday bangalore edition...
#
# Story 390, bring social back social network apps try imagery new york...
#
# Story 391, factor create strong foundation effective leadership economic time december wednesday...
#
# Story 392, ai may impact job money baltimore sun september sunday advance...
#
# Story 393, artificial intelligence aug human ing replace say adobe ceo economic...
#
# Story 394, et explain el mu v open curious case sour grape...
#
# Story 395, peek future ag humanoid robot respond spoken prompt pittsburgh post...
#
# Story 396, skill platform di bag lu others economic time paper edition...
#
# Story 397, pan relief funding child care ending deal newsletter new york...
#
# Story 398, hollywood director union reach deal studio new york time june...
#
# Story 399, doctor cautiously adopt ai aided care many value time patient...
#
# Story 400, el mu found artificial intelligence company may work tesla twitter...
#
# Story 401, ai india tech major build cutting edge ai solution world...
#
# Story 402, indian company make cut bc top global value creator list...
#
# Story 403, wrong turn doom effort apple car new york time march...
#
# Story 404, sa startup ka raise million funding pe firm india alternative...
#
# Story 405, wendy launch drive thru ai program june usa today online...
#
# Story 406, business technology internet taste stunt em wrong ai los angeles...
#
# Story 407, bai rival chat wall street journal abstract october wednesday copyright...
#
# Story 408, tuesday briefing new york time may tuesday est copyright new...
#
# Story 409, skill gap workforce ai advancement make cyber attack threatening india...
#
# Story 410, hottest job corporate america executive charge new york time january...
#
# Story 411, amazon taught alexa speak irish bro new york time international...
#
# Story 412, pocket fm net series raise light others economic time paper...
#
# Story 413, new head step protecting election priority new york time february...
#
# Story 414, prompt progress gen text code tool boost productivity economic time...
#
# Story 415, scary part ai lot writer new york observer january monday...
#
# Story 416, want high paying freelance gig look top industry baltimore sun...
#
# Story 417, apple talking google iphone new york time march wednesday late...
#
# Story 418, virtual assistant taught appreciate busy critic notebook new york time...
#
# Story 419, existent threat new york time june tuesday late edition final...
#
# Story 420, jeff chris wood increase bet reduces investment economic time july...
#
# Story 421, mental health chat named tessa went rogue wall street journal...
#
# Story 422, chat rely work newspaper group say new york time november...
#
# Story 423, week wild child boom california issue new york time may...
#
# Story 424, el mu v open curious case sour grape economic time...
#
# Story 425, india fastest growing office palo alto last five year ceo...
#
# Story 426, genus control new york time october friday est copyright new...
#
# Story 427, fed rate hike fight inflation hurt economy long term study...
#
# Story 428, using student opinion new york time may tuesday est copyright...
#
# Story 429, apple new plan app store many developer hate new york...
#
# Story 430, alexa sir fr away big lead race new york time...
#
# Story 431, google introduces new pixel phone tablet ai tech open bard...
#
# Story 432, machine morality big idea think new york time june monday...
#
# Story 433, insider trust safety ex talk ai content mode alex pop...
#
# Story 434, national security consideration likely ai sun pic economic time may...
#
# Story 435, boost productivity company sure hope new york time april monday...
#
# Story 436, knowing risk carnegie mellon expert weigh federal ai guideline pittsburgh...
#
# Story 437, open loss nearly double million cost build report economic time...
#
# Story 438, reliance partner developing ai india economic time september saturday copyright...
#
# Story 439, building trust robot economic time paper edition january monday delhi...
#
# Story 440, china rush dominate come twist depends technology new york time...
#
# Story 441, wi expands google cloud partnership advance enterprise adoption genus ai...
#
# Story 442, use family time new york time july friday est copyright...
#
# Story 443, open bet tech startup hint future artificial intelligence new york...
#
# Story 444, democrat fear falling behind go ai race st wrestle deploy...
#
# Story 445, bard google pull trigger new york time march wednesday late...
#
# Story 446, instant video represent next leap technology new york time april...
#
# Story 447, air india tap airbus training unit economic time paper edition...
#
# Story 448, india play key role building hardy supply chain say qu...
#
# Story 449, ai open new way hacker harm wall street journal abstract...
#
# Story 450, future new york time april saturday late edition final copyright...
#
# Story 451, global ai season su see big opening data centre economic...
#
# Story 452, inflation data risk shut deal newsletter new york time september...
#
# Story 453, gen firm em raise million economic time paper edition march...
#
# Story 454, company created chat thrown turmoil microsoft hire ousted ceo company...
#
# Story 455, stuck holiday gift happened used ai help christmas shopping usa...
#
# Story 456, high stock info steal deal economic time june tuesday copyright...
#
# Story 457, ahead market thing decide street action tuesday economic time april...
#
# Story 458, ax see coming shift strategy new york time april thursday...
#
# Story 459, report worker india behind walk tech amazon spokesperson took issue...
#
# Story 460, va meta need help finding reason existence baltimore sun april...
#
# Story 461, fake fact shaping first ai election voter worry usa today...
#
# Story 462, leader press advantage congress china tension rise new york time...
#
# Story 463, silicon valley machine new york time may sunday late edition...
#
# Story 464, cc pick aw cloud drive genome research project economic time...
#
# Story 465, give bear bull hug economic time january sunday copyright bennett...
#
# Story 466, getting lost sense multiple se new york time december thursday...
#
# Story 467, technical skill eclipse humanity matter ever guest essay new york...
#
# Story 468, boom prompt test copyright law new york time december saturday...
#
# Story 469, survey amid change ceo fear company survival baltimore sun january...
#
# Story 470, good tech award new york time december thursday late edition...
#
# Story 471, reviewing board alt brief firing new york time march saturday...
#
# Story 472, european take major step toward regulating new york time june...
#
# Story 473, yellow ai deploy global genus ai bot domestically economic time...
#
# Story 474, skill platform di bag million lu others economic time august...
#
# Story 475, grows data used train ai wall street journal abstract july...
#
# Story 476, open buying firm india ai push economic time august saturday...
#
# Story 477, gen database firm mon get set big india play economic...
#
# Story 478, big tech cut corner harvest data model new york time...
#
# Story 479, apple exploring deal major news publisher new york time december...
#
# Story 480, race prevent worst case scenario machine learning new york time...
#
# Story 481, microsoft make play tech cold war new york time april...
#
# Story 482, pa partner open in state worker pittsburgh post gazette january...
#
# Story 483, warner bros paramount merger make sense deal newsletter new york...
#
# Story 484, plan leave europe open ceo sam alt economic time may...
#
# Story 485, china jd com launch chat product called chat economic time...
#
# Story 486, build data driven culture expert economic time paper edition may...
#
# Story 487, medium go big premium new mobile processor economic time paper...
#
# Story 488, publisher worry chat cut reader new york time international edition...
#
# Story 489, digest new york time november saturday late edition final copyright...
#
# Story 490, dry spell sight green shoot higher budget economic time paper...
#
# Story 491, politics steel deal hang bid japan summit deal newsletter new...
#
# Story 492, ai video startup gan ai raise million economic time may...
#
# Story 493, cc pick aw cloud drive genome research project economic time...
#
# Story 494, apple block epic game using iphone tool e feud new...
#
# Story 495, revolution change work nobody agrees new york time june saturday...
#
# Story 496, google launch gemini stake global ai race google took next...
#
# Story 497, chat mania lure enterprise startup wall street journal abstract march...
#
# Story 498, spur industry detect new york time may saturday late edition...
#
# Story 499, ai reflects demon angel nature wall street journal abstract april...
#
# Story 500, tel tech switch inevitable economic time paper edition november thursday...

# %% [markdown]
# ### Construct the Variables

# %%
import pandas as pd
import re

def count_occurrences(text, phrase):
    # Count occurrences of the phrase in the text (case insensitive)
    return len(re.findall(f'\\b{phrase}\\b', text, flags=re.IGNORECASE))

def variable_construct(input_file_path, output_file_path, phrases):
    # Read original CSV file
    df = pd.read_csv(input_file_path)
    
    # Initialize empty lists to store counts
    counts_risk = []
    counts_privacy = []
    counts_job = []
    counts_wage  = []
    
    # Process each Body_text to count occurrences of the phrases
    for body_text in df['Body_text']:
        count_risk = count_occurrences(body_text, phrases['risk'])
        count_privacy = count_occurrences(body_text, phrases['privacy'])
        count_job = count_occurrences(body_text, phrases['job'])
        count_wage = count_occurrences(body_text, phrases['wage'])
        
        counts_risk.append(count_risk)
        counts_privacy.append(count_privacy)
        counts_job.append(count_job)
        counts_wage.append(count_wage)
    
    # Add new columns to DataFrame
    df['risk'] = counts_risk
    df['privacy'] = counts_privacy
    df['job'] = counts_job
    df['wage'] = count_wage
    
    # Drop 'Body_text' column from DataFrame
    df.drop(columns=['Body_text'], inplace=True)
    
    # Save DataFrame to new CSV file
    df.to_csv(output_file_path, index=False)

# Example usage
input_file_path  = 'df_construct_300.csv'
output_file_path = 'df_variables_300.csv'

# Define phrases to count
phrases = {
    'risk': 'risk',
    'privacy': 'privacy',
    'job': 'job',
    'wage': 'wage'
}

variable_construct(input_file_path, output_file_path, phrases)
