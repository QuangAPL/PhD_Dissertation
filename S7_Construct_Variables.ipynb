# %% [markdown]
# ### Construct DataFrame

# %%
import pandas as pd
import json

def dataframe_construct(input_file_path, output_file_path):
    # Read JSON file
    with open(input_file_path, 'r', encoding='utf-8') as file:
        # Load JSON data
        data = json.load(file)
        
    # Initialize lists to store story_id and body_text
    story_ids = []
    body_texts = []

    # Process each story in the JSON data
    for idx, story in enumerate(data):
        # Extract story_id and body_text
        story_id = idx + 1  # Assuming story_id starts from 1
        body_text = story.strip('"')  # Remove leading/trailing quotes
        
        # Append to lists
        story_ids.append(story_id)
        body_texts.append(body_text)

    # Create DataFrame
    df = pd.DataFrame({'Story_ID': story_ids, 'Body_text': body_texts})

    # Save DataFrame to CSV with headers and without index column
    df.to_csv(output_file_path, index=False, header=True)
    
    # Read CSV file
    df_csv = pd.read_csv(output_file_path)

    # Print first 10 words of each body_text
    print("Printing first 10 words of each story:")
    for index, row in df_csv.iterrows():
        first_10_words = ' '.join(row['Body_text'].split()[:10])
        print(f"Story {row['Story_ID']}, {first_10_words}...")
        print()  # Separate each story

# Example usage
input_file_path = 'tokenizedFine_300.json'
output_file_path = 'df_construct_300.csv'
dataframe_construct(input_file_path, output_file_path)
# Out:
# Printing first 10 words of each story:
# Story 1, amazon thursday announced launch new product multichannel fulfilment enable seller...
#
# Story 2, new york time filed civil lawsuit openai microsoft federal district...
#
# Story 3, valuation tripled le month openai completed deal value san francisco...
#
# Story 4, bengaluru cognizant bagged active early client engagement focussed cognitive generative...
#
# Story 5, editor keep plastic ocean start river boyan slat opinion guest...
#
# Story 6, amazon google meta among company announced guideline race outdo version...
#
# Story 7, technology company leery artificial intelligence priority winning control industry next...
#
# Story 8, november ilya sutskever joined three openai board member force sam...
#
# Story 9, abstract professor around world experimenting oral exam improve teaching learning...
#
# Story 10, company leveraging healthcare data hospital enterprise data publicly available clinical...
#
# Story 11, abstract microsoft linkedin professional networking platform testing generative artificial intelligence...
#
# Story 12, many young artist david salle mentored none ever challenging latest...
#
# Story 13, san francisco multinational semiconductor company advanced micro device amd artificial...
#
# Story 14, apple appeal penalty latest series regulatory setback tech giant apple...
#
# Story 15, office reviewing law apply artificial intelligence technology content creator tech...
#
# Story 16, u leading race releasing generative ai large language model llm...
#
# Story 17, bit rough pr week video meeting chat platform zoom app...
#
# Story 18, seems hollywood fight artificial intelligence ai long one streaming giant...
#
# Story 19, gary gensler studied consequence artificial intelligence year technology lead future...
#
# Story 20, abstract demetria gallegos article journal report workplace technology look reader...
#
# Story 21, abstract dan gallagher heard street column note google microsoft nvidia...
#
# Story 22, kapture cx customer support platform enterprise raised million india alternative...
#
# Story 23, google new pixel let use artificial intelligence add remove element...
#
# Story 24, former infosys president ravi kumar completes one year ceo service...
#
# Story 25, abstract satori fund founder dan nile article barron guide wealth...
#
# Story 26, december turned busiest month risk capital investor announced billion funding...
#
# Story 27, abstract alexander reben taking perspective openai company art world believe...
#
# Story 28, many ad easier make technology pose threat industry already flux...
#
# Story 29, ceo meet iisc iit researcher bengaluru nvidia world maker hardware...
#
# Story 30, abstract nuclear fusion generative bee tracking lot full text year...
#
# Story 31, group legal expert pressing patent agency court policymakers address question...
#
# Story 32, amazon new factory worker complain long hour poor working condition...
#
# Story 33, jet maker share price fell sharply premarket trading monday hundred...
#
# Story 34, accenture started see potential revenue upswing use generative artificial intelligence...
#
# Story 35, good starting point boost innovation new delhi bengaluru india ambitious...
#
# Story 36, abstract andy kessler inside view column contends kink worked generative...
#
# Story 37, unionized allegheny general hospital nurse scheduled vote thursday whether continue...
#
# Story 38, summary summary summary editor pose extinction tech leader warn front...
#
# Story 39, abstract google chatgpt rival bard rolled new version chatbot language...
#
# Story 40, amid widespread weakness technology stock worldwide american cybersecurity provider palo...
#
# Story 41, challenge help u celebrate anniversary including one open teacher teenager...
#
# Story 42, listen follow hard fork apple spotify amazon youtube openai released...
#
# Story 43, india known world tech backbone without reason indian software service...
#
# Story 44, generative ai already made huge impact technology used daily basis...
#
# Story 45, mustafa suleyman remembers epochal moment grasped artificial intelligence potential paleolithic...
#
# Story 46, company working trim expense laid employee worked core engineering google...
#
# Story 47, faced particularly tough question round intern year run straight bathroom...
#
# Story 48, white house imposed billion new duty chinese import unclear much...
#
# Story 49, recent month major company announced wave layoff meanwhile development artificial...
#
# Story 50, artificial intelligence act collaborator help artist produce new work personal...
#
# Story 51, ten million job automated generative artificial intelligence maker new technology...
#
# Story 52, report mckinsey come debate rage potential economic effect chatbots labor...
#
# Story 53, china produced huge number top engineer recent year new research...
#
# Story 54, archbishop mansion san francisco built stately hotel northeast corner alamo...
#
# Story 55, chandra first public comment mumbai tata consultancy service tc sacked...
#
# Story 56, tech giant partner openai accused infringing copyright train technology online...
#
# Story 57, last year openai released first free version chatgpt within hour...
#
# Story 58, bengaluru cumulative hiring major cognizant capgemini globally declined employee compared...
#
# Story 59, anthropic specializes generative artificial intelligence hot investment silicon valley new...
#
# Story 60, track fake drake weeknd vocal went viral listen song sang...
#
# Story 61, hedge fund mogul bankrolling european patent fight intel dell amazon...
#
# Story 62, et host sam altman june mumbai sam altman openai chatgpt...
#
# Story 63, decade easy get help repairing iphone cracked screen replaced minute...
#
# Story 64, chinese company inc unit jd cloud launch product similar chatgpt...
#
# Story 65, string uncanny video show generative advertising common chew cultural subconscious...
#
# Story 66, johnny taylor tackle human resource question part series usa today...
#
# Story 67, john szarkowski legendary former curator museum modern art described photography...
#
# Story 68, shopify mercari retailer rolling chatbots help buyer holiday shopping season...
#
# Story 69, new delhi multinational retail hypermarket walmart sourced billion good indian...
#
# Story 70, american dream slowly transforming nightmare indian diaspora news yet another...
#
# Story 71, collection free link help participating multimedia challenge high school education...
#
# Story 72, american software multinational adobe acquired provides artificial intelligence ai video...
#
# Story 73, mumbai artificial intelligence ai replace fte technology role annually next...
#
# Story 74, abstract microsoft juggernaut thanks artificial intelligence want seen ethical employer...
#
# Story 75, abstract jo craven mcginty article journal report future everything feature...
#
# Story 76, latest version data bill drop clause created exception bengaluru generative...
#
# Story 77, customer experience platform kapture cx raised million part latest round...
#
# Story 78, literary theory robot dennis yi tenen software engineer turned literature...
#
# Story 79, artificial intelligence ai going augment human ingenuity replace shantanu narayen...
#
# Story 80, large language model type neural network learns skill including generating...
#
# Story 81, issue cut across partisan geographical difference ilana beller organizing manager...
#
# Story 82, social networking giant long contentious relationship political ad reckoning wave...
#
# Story 83, percent licensed child care provider united state received grant used...
#
# Story 84, global service consulting major cognizant tapping generative ai gen ai...
#
# Story 85, law taking effect march forced apple loosen grip app store...
#
# Story 86, silicon gokul rajaram solo capitalist operator prolific angel investor backed...
#
# Story 87, american investment bank goldman sachs set facility india train engineer...
#
# Story 88, independence day weekend saw crore gross collection record indian cinema...
#
# Story 89, thena customer communication intelligence platform help business manage customer messaging...
#
# Story 90, journalist facing deep fake sagging trust global unrest unprecedented trump...
#
# Story 91, mumbai abu artificial intelligence ai investment firm holding partnered seetha...
#
# Story 92, news union represents film television actor voted monday night authorize...
#
# Story 93, sorry dave afraid line renegade computer hal directly contradicted direct...
#
# Story 94, cast mind forward day another presidential election one went smoothly...
#
# Story 95, new tool enable silicon valley dream bot customize learning pupil...
#
# Story 96, openai ceo sam altman picked japan destination first overseas trip...
#
# Story 97, longer believe anything see seeing believing long time photo faked...
#
# Story 98, image first glance appear genuine interspersed real photograph campaign video...
#
# Story 99, vote prevented doomsday scenario three major hollywood union striking simultaneously...
#
# Story 100, artificial intelligence taking human job last month eliminated job according...
#
# Story 101, linkedin cofounder reid hoffman mustafa suleyman founding researcher google deepmind...
#
# Story 102, march planned upcoming trip france amy kolsky experienced international traveler...
#
# Story 103, go vacation summer question simple enough possibility endless feeling adventurous...
#
# Story 104, generative technology write poetry computer program create image teddy bear...
#
# Story 105, year college graduate entering workforce amid called generative ai gold...
#
# Story 106, track heart sleeve went viral taken streaming service week may...
#
# Story 107, mobile app openai chatgpt downloaded million time globally since launch...
#
# Story 108, artificial intelligence ai going augment human ingenuity replace shantanu narayen...
#
# Story 109, crowded generative artificial intelligence race saw another rising star inflection...
#
# Story 110, many site get least half traffic search engine fuller result...
#
# Story 111, table stake small company compete like microsoft google billion dollar...
#
# Story 112, office overlooking taipei mountain surround taiwanese capital morris chang recently...
#
# Story 113, businessman bill gate logged wednesday reddit anything session touched different...
#
# Story 114, weekend column used season campus protest opportunity discus evolution columbia...
#
# Story 115, amazon rolling new generative ai feature summarizes product review customer...
#
# Story 116, amid overwhelming demand niche technology skill financial service industry india...
#
# Story 117, shock pause central bank spook already jittery market one analyst...
#
# Story 118, abstract technology company leery artificial intelligence priority winning control industry...
#
# Story 119, federal communication commission thursday outlawed robocalls contain voice generated artificial...
#
# Story 120, recent week american lawmaker moved ban app tiktok president biden...
#
# Story 121, meta final phase rebuilding recommendation model part company tech roadmap...
#
# Story 122, visit allegheny health network doctor talk medical problem soon machine...
#
# Story 123, mother daughter advocating better protection victim nude image teen female...
#
# Story 124, whether realize great many writer using daily decade spell check...
#
# Story 125, poll generated artificial intelligence embedded next guardian article microsoft news...
#
# Story 126, introduction definition proposed consent artefact digital personal data protection dpdp...
#
# Story 127, bengaluru american chipmaker nvidia reliance industry india largest company market...
#
# Story 128, china produced huge number top engineer recent year new research...
#
# Story 129, bengaluru adobe acquired run generative artificial intelligence gen ai video...
#
# Story 130, johnny taylor tackle human resource question part series usa today...
#
# Story 131, new delhi india plan establish principle act guardrail artificial intelligence...
#
# Story 132, leader expected hold first talk common regulatory approach generative artificial...
#
# Story 133, et explainer new delhi eight u news publisher tuesday filed...
#
# Story 134, google announced tuesday new set artificial intelligence feature various workspace...
#
# Story 135, editor even think checking bag david mack opinion guest essay...
#
# Story 136, country singer romance novelist video game artist voice actor appealing...
#
# Story 137, concept jargon need understand chatgpt compiled list phrase concept useful...
#
# Story 138, et host sam altman june mumbai sam altman openai chatgpt...
#
# Story 139, office reviewing law apply artificial intelligence technology content creator tech...
#
# Story 140, abstract dan gallagher heard street column note share photoshop maker...
#
# Story 141, new artificial intelligence technology roiling silicon valley obvious way use...
#
# Story 142, abstract tom paronis letter responds peggy noonan april declaration column...
#
# Story 143, mother daughter advocating better protection victim nude image teen female...
#
# Story 144, computer keyboard making room artificial intelligence chatbot button microsoft unveils...
#
# Story 145, december day set revolution across videogame industry appeared start innocuously...
#
# Story 146, abstract new study concludes accountant among professional whose career exposed...
#
# Story 147, nobody worry able afford critical health care gov philip murphy...
#
# Story 148, expectation never great exceed performance parameter consummate ease much relative...
#
# Story 149, agrees new york time june saturday est copyright new york...
#
# Story 150, image generated lensa ai social medium cost noticed many friend...
#
# Story 151, legislator two dozen state working bill passed law combat sexually...
#
# Story 152, good morning betty bringing top headline day need help holiday...
#
# Story 153, starting thursday apple watch series watch ultra longer detect people...
#
# Story 154, year tech world one big leap even bigger pratfall fall...
#
# Story 155, investment frenzy generative artificial intelligence gripped silicon valley tool generate...
#
# Story 156, google soon require political ad using artificial intelligence accompanied prominent...
#
# Story 157, new hampshire attorney general office monday investigating report apparent robocall...
#
# Story 158, planning paralysis still clutch day family left october break trip...
#
# Story 159, strike screenwriter secured significant guardrail use artificial intelligence one first...
#
# Story 160, artificial intelligence tool replace much wall street work raising tough...
#
# Story 161, bengaluru new database company mongodb see great opportunity india large...
#
# Story 162, national security official warning potential new technology upend war cyber...
#
# Story 163, wilmerhale law firm investigating sam altman present finding company board...
#
# Story 164, artificial intelligence ai risk management solution provider sydelabs thursday raised...
#
# Story 165, bengaluru american chipmaker nvidia reliance industry india largest company market...
#
# Story 166, new delhi india plan establish principle act guardrail artificial intelligence...
#
# Story 167, artificial intelligence collaborated news organization time accused copyright infringement telling...
#
# Story 168, many uncertainty haunt field journalism today among reach audience build...
#
# Story 169, heated big tech artificial intelligence race making apple nervous stagnant...
#
# Story 170, partnership extend long relationship company helped deliver everything map search...
#
# Story 171, week gold rush artificial intelligence become mania four leading artificial...
#
# Story 172, abstract generative ai already used create advertising material reduce grunt...
#
# Story 173, company edge blocking creation distribution child sexual abuse material seen...
#
# Story 174, sundar pichai google chief executive testified tuesday second time two...
#
# Story 175, artificial intelligence making way medical office throughout pennsylvania including pittsburgh...
#
# Story 176, lawsuit cap year regulatory scrutiny apple wildly popular suite device...
#
# Story 177, google ceo sundar pichai never actually declared code red within...
#
# Story 178, washington ap conspiracy trial stretched across world politics entertainment touching...
#
# Story 179, numerous story chatbots gone wrong since onset chatgpt late perhaps...
#
# Story 180, fortnite creator accuses google stifling app competition challenge top federal...
#
# Story 181, abstract james mackenzie letter responds peggy noonan april declaration column...
#
# Story 182, artificial intelligence ai reduce barrier creativity developer creator evan spiegel...
#
# Story 183, abstract shortage advanced chip power new system set race lock...
#
# Story 184, bengaluru india fastest growing market microsoft github internet hosting service...
#
# Story 185, transformation telecommunication company india around world tech company telco techco...
#
# Story 186, used artificial intelligence daily life yet asked question room ten...
#
# Story 187, independence day weekend saw crore gross collection record indian cinema...
#
# Story 188, artificial intelligence new classical music recent rapid development composer worried...
#
# Story 189, magazine ethicist columnist using artificial intelligence assist mundane task work...
#
# Story 190, heading tomorrow next year beyond today newsletter last series look...
#
# Story 191, premium people tell thing know grow importance machine say jim...
#
# Story 192, corporate leader feeling emboldened another legal defeat federal trade commission...
#
# Story 193, semiconductor firm advanced micro device amd india arm contributes nearly...
#
# Story 194, link image paris olympics set begin july professor computer science...
#
# Story 195, steven spielberg science fiction film minority report set u showcase...
#
# Story 196, artificial intelligence tool conjure whimsical artwork image written command started...
#
# Story 197, federal trade commission launched investigation chatgpt creator openai whether artificial...
#
# Story 198, corporate diversity equity inclusion program come attack company rebranding effort...
#
# Story 199, boarding plane head another country alone often emotional experience excitement...
#
# Story 200, million article new york time used train chatbots compete lawsuit...
#
# Story 201, good morning daniel de visé daily money feel paycheck going...
#
# Story 202, disprz corporate learning skilling platform raised million series funding round...
#
# Story 203, artificial intelligence ai gain prominence among business past week alone...
#
# Story 204, apple plan announce bring generative iphones company significant reorganization decade...
#
# Story 205, matthew hitchcock family physician chattanooga helper record patient visit smartphone...
#
# Story 206, around noon sam altman chief executive openai logged video call...
#
# Story 207, company annual conference google demonstrated dozen product feature work artificial...
#
# Story 208, american worried artificial intelligence technology chatgpt used worsen social ill...
#
# Story 209, computer keyboard making room artificial intelligence chatbot button microsoft unveils...
#
# Story 210, chatgpt iteration broader advancement generative ai raising stake company expected...
#
# Story 211, bengaluru kapture cx customer support platform enterprise raised million india...
#
# Story 212, quick name five classic american magazine say sport illustrated even...
#
# Story 213, number republican lawmaker taken money company vilified party presidential hopeful...
#
# Story 214, mumbai ai artificial intelligence may buzzword marketing right cxos seem...
#
# Story 215, major technology company signed pact friday voluntarily adopt reasonable precaution...
#
# Story 216, hiking interest rate aggressively federal reserve done past month fight...
#
# Story 217, meta introduced artificially intelligent character based jane austen snoop dogg...
#
# Story 218, tool powered entirely artificial intelligence getting first test pennsylvania democrat...
#
# Story 219, sharing new technology called sora small group early tester try...
#
# Story 220, amazon touchless technology allows customer grab need shelf walk without...
#
# Story 221, year since steel tycoon andrew carnegie walked street pittsburgh talk...
#
# Story 222, artificial intelligence argued online chatbot chatgpt substitute new york time...
#
# Story 223, mountain view alphabet inc google conversational generative ai chatbot rolled...
#
# Story 224, tech giant publicly released latest technology people build chatbots rival...
#
# Story 225, anyone looking beautiful photograph desert landscape find many choice getty...
#
# Story 226, customer engagement loyalty software provider capillary technology extended latest series...
#
# Story 227, abstract henry kissinger eric schmidt daniel huttenlocher opinion column discus...
#
# Story 228, school year begin thinking evolved sat chatgpt workshop month teacher...
#
# Story 229, listen follow hard fork apple spotify stitcher amazon google sit...
#
# Story 230, nearly year oren etzioni among optimistic artificial intelligence researcher etzioni...
#
# Story 231, award announced president biden plant arizona biggest government made new...
#
# Story 232, nvidia predicted another massive sale gain current quarter helping justify...
#
# Story 233, san francisco reddit long hot spot conversation internet million people...
#
# Story 234, abstract dan gallagher heard street column note surge nvidia share...
#
# Story 235, blow pakistan military niue fight domain warned russia put nuclear...
#
# Story 236, increasingly mound synthetic output drift across feed search stake go...
#
# Story 237, editor school cope grow student using kevin roose shift column...
#
# Story 238, individual right know personal data used law digital personal data...
#
# Story 239, story syndicated substack newsletter big technology subscribe free chatbots job...
#
# Story 240, conversational artificial intelligence ai startup monday announced official launch bharatgpt...
#
# Story 241, tech giant wrapping argument federal monopoly trial framed good corporate...
#
# Story 242, spoke chinese baidu ernie american chatgpt found last month china...
#
# Story 243, producer pop singer long proponent technological experimentation voice using new...
#
# Story 244, mistral french considered promising challenger openai google getting support european...
#
# Story 245, antitrust enforcer opening investigation relationship leading artificial intelligence startup chatgpt...
#
# Story 246, cincinnati major hospital system using artificial intelligence technology american wary...
#
# Story 247, abstract generative artificial intelligence sent tech stock soaring year reminding...
#
# Story 248, generative boom fueling arm race among semiconductor manufacturer produce engine...
#
# Story 249, everyone seems complain hard get good help day even artificial...
#
# Story 250, emergence generative artificial intelligence moving much quickly previous technology wave...
#
# Story 251, infosys american depository receipt adrs fell new york stock exchange...
#
# Story 252, many feared artificial intelligence kill job hospital insurance company others...
#
# Story 253, note pandora box anything look ordinary may produce unpredictable harmful...
#
# Story 254, generative already changing game made blizzard entertainment training image generator...
#
# Story 255, focus much discussion replace job nothing inevitable easy fear machine...
#
# Story 256, instagram facebook snapchat several newcomer betting artificial intelligence rejuvenate fun...
#
# Story 257, adoption generative artificial intelligence customer engagement picking pace instance conversational...
#
# Story 258, world text know real artificial intelligence software chatgpt writes considers...
#
# Story 259, embattled car subsidiary general motor face uncertain future california regulator...
#
# Story 260, shopify mercari retailer rolling chatbots help buyer holiday shopping season...
#
# Story 261, amid intractable real estate crisis fake luxury house offer delusion...
#
# Story 262, elon musk ceo twitter ev maker tesla planning launch new...
#
# Story 263, listen follow hard fork apple spotify stitcher amazon google sam...
#
# Story 264, chatgpt creator openai revealed significant upgrade conversational ai model chatgpt...
#
# Story 265, report mckinsey come debate rage potential economic effect chatbots labor...
#
# Story 266, new delhi generative artificial intelligence ai tool may necessarily lead...
#
# Story 267, product pitched helpmate journalist demonstrated executive new york time washington...
#
# Story 268, literary theory robot dennis yi tenen playful new book artificial...
#
# Story 269, new delhi transformation telecommunication company india around world tech company...
#
# Story 270, draft law european parliament become world attempt address potentially harmful...
#
# Story 271, amazon box salesforce oracle others recently rolled product help workplace...
#
# Story 272, thanks strong capital market average annual total shareholder return surged...
#
# Story 273, abstract much chatgpt generates poetry new system devise blueprint microscopic...
#
# Story 274, reception openai first developer conference san francisco last month crowd...
#
# Story 275, hundred client meeting three month agenda newly appointed microsoft india...
#
# Story 276, abstract tool promise fix common red flag used identify bogus...
#
# Story 277, inbox management wondered robot five hour enough time watch mets...
#
# Story 278, plan meal find gift create story using generative hello back...
#
# Story 279, laguna beach high school administrator launched investigation student allegedly created...
#
# Story 280, holiday know mean endless stream wish list gift guide splashy...
#
# Story 281, abstract dan gallagher heard street column prospect chip maker micron...
#
# Story 282, president biden announced regulation monday seemed little bit everyone regulate...
#
# Story 283, california shared nude photo classmate friend without consent student conceivably...
#
# Story 284, every tuesday friday ezra klein invite conversation something matter today...
#
# Story 285, ceo meet iisc iit researcher bengaluru nvidia world maker hardware...
#
# Story 286, generative tool annotate long document make flashcard produce practice quiz...
#
# Story 287, inhibiting trade mean anywhere global gdp risk bob sternfels global...
#
# Story 288, abstract pricewaterhousecoopers llp plan invest billion generative technology u operation...
#
# Story 289, new delhi taiwanese chipmaker mediatek gunning premium segment coming year...
#
# Story 290, everyone love reading principle anyway nobody right surely midst many...
#
# Story 291, de moines iowa cost building artificial intelligence product chatgpt hard...
#
# Story 292, last trending technology fell radar quickly emerged metaverse revolutionary technology...
#
# Story 293, openai creator chat gpt unveiled sora latest upgrade generative artificial...
#
# Story 294, abstract labor contract negotiation heat hollywood union representing writer actor...
#
# Story 295, independence day weekend saw crore gross collection record indian cinema...
#
# Story 296, openai new chatbot raising fear cheating homework potential educational tool...
#
# Story 297, la vega india need regulator artificial intelligence ai need balance...
#
# Story 298, investment billion amazon seeking bigger footprint development one already established...
#
# Story 299, ousted leader chatgpt maker openai return company fired day ago...
#
# Story 300, leader expected hold first talk common regulatory approach generative artificial...

# %% [markdown]
# ### Construct the Variables

# %%
import pandas as pd
import re

def count_occurrences(text, phrase):
    # Count occurrences of the phrase in the text (case insensitive)
    return len(re.findall(f'\\b{phrase}\\b', text, flags=re.IGNORECASE))

def variable_construct(input_file_path, output_file_path, phrases):
    # Read original CSV file
    df = pd.read_csv(input_file_path)
    
    # Initialize empty lists to store counts
    counts_risk = []
    counts_privacy = []
    counts_job = []
    counts_wage  = []
    
    # Process each Body_text to count occurrences of the phrases
    for body_text in df['Body_text']:
        count_risk = count_occurrences(body_text, phrases['risk'])
        count_privacy = count_occurrences(body_text, phrases['privacy'])
        count_job = count_occurrences(body_text, phrases['job'])
        count_wage = count_occurrences(body_text, phrases['wage'])
        
        counts_risk.append(count_risk)
        counts_privacy.append(count_privacy)
        counts_job.append(count_job)
        counts_wage.append(count_wage)
    
    # Add new columns to DataFrame
    df['risk'] = counts_risk
    df['privacy'] = counts_privacy
    df['job'] = counts_job
    df['wage'] = count_wage
    
    # Drop 'Body_text' column from DataFrame
    df.drop(columns=['Body_text'], inplace=True)
    
    # Save DataFrame to new CSV file
    df.to_csv(output_file_path, index=False)

# Example usage
input_file_path  = 'df_construct_300.csv'
output_file_path = 'df_variables_300.csv'

# Define phrases to count
phrases = {
    'risk': 'risk',
    'privacy': 'privacy',
    'job': 'job',
    'wage': 'wage'
}

variable_construct(input_file_path, output_file_path, phrases)
