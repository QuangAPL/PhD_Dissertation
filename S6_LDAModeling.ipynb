# %% [markdown]
# ### Process Overview:
# - ##### Inputs: vectorized_200.csv
#
# - ##### Outputs: topic display

# %%
import pandas as pd
from sklearn.decomposition import LatentDirichletAllocation
from scipy.sparse import csr_matrix

def display_topics(file_path, num_top_words, feature_names):
    # Step 1: Load TF-IDF vectors
    tfidf_vectors = pd.read_csv(file_path)
    tfidf_matrix = csr_matrix(tfidf_vectors.values)

    num_topics = 12
    lda_model = LatentDirichletAllocation(n_components=num_topics, random_state=42)
    lda_model.fit(tfidf_matrix)

    for topic_idx, topic in enumerate(lda_model.components_):
        print("Topic %d:" % (topic_idx))
        print(" ".join([feature_names[i] for i in topic.argsort()[:-num_top_words - 1:-1]]))

# Example usage
file_path = 'tfidf_vectorized_300.csv'
num_top_words = 50
feature_names = pd.read_csv(file_path).columns
display_topics(file_path, num_top_words, feature_names)
# Out:
# Topic 0:
# salle water desantis linkedin iowa llama austen sexually chandrasekaran supplier moines coffee breach recruitment suing volatility mullet ny shareholder ingested beach traveler grand fauci jewel kelce spit ren weave staffing davis snoop dogg park genuine depicting relief beer destination clearview governor scandal defendant gallery generic filling adapted mit anthony ftc
# Topic 1:
# merchat repair cruise shop cent oracle painting blizzard glossary budget parameter discipline favour sentence technique printer output therefore analytics ergonomic violet painter camp surveyed algorithm luddite jacob update characteristic taiwanese supporting learns electronics loeb personalized processor vogt alexander unexpected wonderful suppress linguistic austin museum warcraft moore angelo generic acemoglu wealth
# Topic 2:
# amd ftc facstamp orth cpu fac peds solo traveling church advertiser walla facstamps athlete pentagon cincinnati trihealth gpus destination bashing ensign mit su targeted christ forum driver micro processor opening compute fictional traveler billing multinational disease tsmc welcomed exponentially iowa cheat proposition liu anybody agreeing structural trigger vivek prefer shield
# Topic 3:
# reben gene ar mckinsey profluent classroom crispr edit teaching residence educator laguna wang thena saxena composer beach fontenot snap apis microscopic batch mechanism cheating biological tutor conjure birth thorn nature compute displace ftc dna slack gpus abortion jury laidlow mansion clause division occupation exploded demo willner cosmology juror whimsical universe
# Topic 4:
# guardian journalism plastic button zoom keyboard perlmutter fulfilment pittsburgh mohapatra bubble fcc oral window kansler walk brainstorm pixel summarizes exam seller pc watermarking rolling exemption dell homestead techfest singla logo pwc artefact tos weber dpdp pollution capitalize wilmerhale sebastian local reminding editing cheat greene laptop analytics sesno trigger redesign experimenting
# Topic 5:
# kapture metaverse secondary cx axios crore capillary mongodb cactus zimmermann doc saas alternative ravinutala vandehei ecommerce flashcard skilling rapper gmail dethrone matching cinema dead lasted runway deceased quiz superstar cc michel kamath recurring tv kenner reddy workspace revolutionize analytics trial hacker fugees brand mile anand flag studying provides saudi arabia
# Topic 6:
# tenen amd animal bag guidebook walmart supplier murphy sourcing gensler steves ezra klein governor su yellow passenger syllabus takeover being pga nonfiction melanie module douthat wheel metaphor dennis yi parliament dunne saudi literature lobby overhead station luggage map columbia garbage checked challenger multinational assign ideological meditation secular moral contemporary gov
# Topic 7:
# inflection sora reddit rephrase pi hoffman chang goldman sachs suleyman bharatgpt chandok hanooman angel tsr deepmind tsmc dealer corover ticket nature linkedin azure adoption reid github memo niue llm ford pakistan api candle observer backed horwitz dealership cite khosla perlmutter develops clifford provides showing cash unpredictable stability gpt hottest road
# Topic 8:
# casey ernie marion lozano fork sydelabs davis newton powell roose land ftc szuchman paula ittoop elisheba befake daniel cohn niemisto poyant gallogly miranda lopresti nell vulnerability rowan caitlin jeffrey drawing kate rachel kevin lanman sophia kumari jen tutoring annually intentionality baidu emad alyssa soup mostaque podcasts bottle selfies khanmigo additionally
# Topic 9:
# highmark agility lensa mensch sachs mistral pittsburgh goldman gate mint kreps grandchild morgan documentation vertex replied samtani beer shelton digit humanoid clarke purchasing pizzi cmu selfies abridge administrative avatar hitchcock prisma presence thompson chatfished walmart wealth recovers authorize banking burden fat malware fairy operational paperwork chui treatment lesson burnout inbox
# Topic 10:
# patient doctor travel hospital llm bot iphone shopping healthcare mckinsey observer everyone physician gate lab medical nurse epic instagram learn ask clinical trial algorithm brand yesterday holiday care recipe powered medicine fee journalism option contest discovery illustrated tip iphones shopper banking minute insurance meal alison output purchase traffic podcast handle
# Topic 11:
# ai company new technology openai india abstract time google chatgpt year microsoft york image tech generative tool data intelligence use model people one artificial apple job business work right system billion product may chatbot altman copyright million human make executive industry help word news customer section video used report school

# %% [markdown]
# 5. Assigning Categories to the Topics
# - This step we have to do manually by named each topics based on its key words

# %%
import pandas as pd
from sklearn.decomposition import LatentDirichletAllocation
from scipy.sparse import csr_matrix

def display_topics_with_categories(model, feature_names, num_top_words, topic_categories):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic %d: %s" % (topic_idx, topic_categories.get(topic_idx, "Undefined")))
        top_words = [feature_names[i] for i in topic.argsort()[:-num_top_words - 1:-1]]
        print("Top Words:", ", ".join(top_words))
        print()

# Define categories for each topic
topic_categories = {
    0: "Technology and Innovation",
    1: "Politics and Security",
    2: "Legal and Regulatory Compliance",
    3: "Cruptocurrency and Blockchain Technology",
    4: "Communication and Collaboration Tools",
    5: "Financial Markets and Investment Strategies",
    6: "Corporate Ventures and Partnerships",
    7: "Healthcare and Medical Practices",
    8: "AI. and Technology Companies",
    9: "Corporate Governance and Compliance Issues",
    10: "Social Impact and Ethical Considerations",
    11: "Technology Research and Development",
   
}

# Example usage: Assuming you have already defined and fitted the LDA model
num_topics = 12  # Assuming you have 12 topics
feature_names = pd.read_csv('tfidf_vectorized_300.csv').columns
num_top_words = 30  # Assuming you want to display 30 top words per topic
lda_model = LatentDirichletAllocation(n_components=num_topics, random_state=42)
lda_model.fit(csr_matrix(pd.read_csv('tfidf_vectorized_300.csv').values))
display_topics_with_categories(lda_model, feature_names, num_top_words, topic_categories)
# Out:
# Topic 0: Technology and Innovation
# Top Words: salle, water, desantis, linkedin, iowa, llama, austen, sexually, chandrasekaran, supplier, moines, coffee, breach, recruitment, suing, volatility, mullet, ny, shareholder, ingested, beach, traveler, grand, fauci, jewel, kelce, spit, ren, weave, staffing
#
# Topic 1: Politics and Security
# Top Words: merchat, repair, cruise, shop, cent, oracle, painting, blizzard, glossary, budget, parameter, discipline, favour, sentence, technique, printer, output, therefore, analytics, ergonomic, violet, painter, camp, surveyed, algorithm, luddite, jacob, update, characteristic, taiwanese
#
# Topic 2: Legal and Regulatory Compliance
# Top Words: amd, ftc, facstamp, orth, cpu, fac, peds, solo, traveling, church, advertiser, walla, facstamps, athlete, pentagon, cincinnati, trihealth, gpus, destination, bashing, ensign, mit, su, targeted, christ, forum, driver, micro, processor, opening
#
# Topic 3: Cruptocurrency and Blockchain Technology
# Top Words: reben, gene, ar, mckinsey, profluent, classroom, crispr, edit, teaching, residence, educator, laguna, wang, thena, saxena, composer, beach, fontenot, snap, apis, microscopic, batch, mechanism, cheating, biological, tutor, conjure, birth, thorn, nature
#
# Topic 4: Communication and Collaboration Tools
# Top Words: guardian, journalism, plastic, button, zoom, keyboard, perlmutter, fulfilment, pittsburgh, mohapatra, bubble, fcc, oral, window, kansler, walk, brainstorm, pixel, summarizes, exam, seller, pc, watermarking, rolling, exemption, dell, homestead, techfest, singla, logo
#
# Topic 5: Financial Markets and Investment Strategies
# Top Words: kapture, metaverse, secondary, cx, axios, crore, capillary, mongodb, cactus, zimmermann, doc, saas, alternative, ravinutala, vandehei, ecommerce, flashcard, skilling, rapper, gmail, dethrone, matching, cinema, dead, lasted, runway, deceased, quiz, superstar, cc
#
# Topic 6: Corporate Ventures and Partnerships
# Top Words: tenen, amd, animal, bag, guidebook, walmart, supplier, murphy, sourcing, gensler, steves, ezra, klein, governor, su, yellow, passenger, syllabus, takeover, being, pga, nonfiction, melanie, module, douthat, wheel, metaphor, dennis, yi, parliament
#
# Topic 7: Healthcare and Medical Practices
# Top Words: inflection, sora, reddit, rephrase, pi, hoffman, chang, goldman, sachs, suleyman, bharatgpt, chandok, hanooman, angel, tsr, deepmind, tsmc, dealer, corover, ticket, nature, linkedin, azure, adoption, reid, github, memo, niue, llm, ford
#
# Topic 8: AI. and Technology Companies
# Top Words: casey, ernie, marion, lozano, fork, sydelabs, davis, newton, powell, roose, land, ftc, szuchman, paula, ittoop, elisheba, befake, daniel, cohn, niemisto, poyant, gallogly, miranda, lopresti, nell, vulnerability, rowan, caitlin, jeffrey, drawing
#
# Topic 9: Corporate Governance and Compliance Issues
# Top Words: highmark, agility, lensa, mensch, sachs, mistral, pittsburgh, goldman, gate, mint, kreps, grandchild, morgan, documentation, vertex, replied, samtani, beer, shelton, digit, humanoid, clarke, purchasing, pizzi, cmu, selfies, abridge, administrative, avatar, hitchcock
#
# Topic 10: Social Impact and Ethical Considerations
# Top Words: patient, doctor, travel, hospital, llm, bot, iphone, shopping, healthcare, mckinsey, observer, everyone, physician, gate, lab, medical, nurse, epic, instagram, learn, ask, clinical, trial, algorithm, brand, yesterday, holiday, care, recipe, powered
#
# Topic 11: Technology Research and Development
# Top Words: ai, company, new, technology, openai, india, abstract, time, google, chatgpt, year, microsoft, york, image, tech, generative, tool, data, intelligence, use, model, people, one, artificial, apple, job, business, work, right, system

# %% [markdown]
# 6. Assigning Topics to Documents

# %%
# Obtain document-topic distribution matrix
document_topic_distribution = lda_model.transform(csr_matrix(pd.read_csv('tfidf_vectorized_300.csv').values))

document_topics = []
for i, document in enumerate(document_topic_distribution):
    dominant_topic = document.argmax()  # Identify dominant topic
    topic_label = topic_categories.get(dominant_topic, "Undefined")  # Assign topic label
    document_topics.append({"document_id": i, "topic": topic_label})
    
# Print document-topic assignment
for doc_topic in document_topics:
    print("Document ID:", doc_topic["document_id"], "- Topic:", doc_topic["topic"])
# Out:
# Document ID: 0 - Topic: Technology Research and Development
# Document ID: 1 - Topic: Technology Research and Development
# Document ID: 2 - Topic: Technology Research and Development
# Document ID: 3 - Topic: Technology Research and Development
# Document ID: 4 - Topic: Technology Research and Development
# Document ID: 5 - Topic: Technology Research and Development
# Document ID: 6 - Topic: Technology Research and Development
# Document ID: 7 - Topic: Technology Research and Development
# Document ID: 8 - Topic: Technology Research and Development
# Document ID: 9 - Topic: Technology Research and Development
# Document ID: 10 - Topic: Technology Research and Development
# Document ID: 11 - Topic: Technology Research and Development
# Document ID: 12 - Topic: Technology Research and Development
# Document ID: 13 - Topic: Technology Research and Development
# Document ID: 14 - Topic: Technology Research and Development
# Document ID: 15 - Topic: Technology Research and Development
# Document ID: 16 - Topic: Technology Research and Development
# Document ID: 17 - Topic: Technology Research and Development
# Document ID: 18 - Topic: Technology Research and Development
# Document ID: 19 - Topic: Technology Research and Development
# Document ID: 20 - Topic: Technology Research and Development
# Document ID: 21 - Topic: Technology Research and Development
# Document ID: 22 - Topic: Technology Research and Development
# Document ID: 23 - Topic: Technology Research and Development
# Document ID: 24 - Topic: Technology Research and Development
# Document ID: 25 - Topic: Technology Research and Development
# Document ID: 26 - Topic: Technology Research and Development
# Document ID: 27 - Topic: Technology Research and Development
# Document ID: 28 - Topic: Technology Research and Development
# Document ID: 29 - Topic: Technology Research and Development
# Document ID: 30 - Topic: Technology Research and Development
# Document ID: 31 - Topic: Technology Research and Development
# Document ID: 32 - Topic: Technology Research and Development
# Document ID: 33 - Topic: Technology Research and Development
# Document ID: 34 - Topic: Technology Research and Development
# Document ID: 35 - Topic: Technology Research and Development
# Document ID: 36 - Topic: Technology Research and Development
# Document ID: 37 - Topic: Technology Research and Development
# Document ID: 38 - Topic: Technology Research and Development
# Document ID: 39 - Topic: Technology Research and Development
# Document ID: 40 - Topic: Technology Research and Development
# Document ID: 41 - Topic: AI. and Technology Companies
# Document ID: 42 - Topic: Technology Research and Development
# Document ID: 43 - Topic: Technology Research and Development
# Document ID: 44 - Topic: Technology Research and Development
# Document ID: 45 - Topic: Technology Research and Development
# Document ID: 46 - Topic: Technology Research and Development
# Document ID: 47 - Topic: Technology Research and Development
# Document ID: 48 - Topic: Technology Research and Development
# Document ID: 49 - Topic: Technology Research and Development
# Document ID: 50 - Topic: Technology Research and Development
# Document ID: 51 - Topic: Technology Research and Development
# Document ID: 52 - Topic: Technology Research and Development
# Document ID: 53 - Topic: Technology Research and Development
# Document ID: 54 - Topic: Technology Research and Development
# Document ID: 55 - Topic: Technology Research and Development
# Document ID: 56 - Topic: Technology Research and Development
# Document ID: 57 - Topic: Technology Research and Development
# Document ID: 58 - Topic: Technology Research and Development
# Document ID: 59 - Topic: Technology Research and Development
# Document ID: 60 - Topic: Technology Research and Development
# Document ID: 61 - Topic: Technology Research and Development
# Document ID: 62 - Topic: Technology Research and Development
# Document ID: 63 - Topic: Technology Research and Development
# Document ID: 64 - Topic: Technology Research and Development
# Document ID: 65 - Topic: Technology Research and Development
# Document ID: 66 - Topic: Technology Research and Development
# Document ID: 67 - Topic: Technology Research and Development
# Document ID: 68 - Topic: Technology Research and Development
# Document ID: 69 - Topic: Technology Research and Development
# Document ID: 70 - Topic: Technology Research and Development
# Document ID: 71 - Topic: Technology Research and Development
# Document ID: 72 - Topic: Technology Research and Development
# Document ID: 73 - Topic: Technology Research and Development
# Document ID: 74 - Topic: Technology Research and Development
# Document ID: 75 - Topic: Technology Research and Development
# Document ID: 76 - Topic: Technology Research and Development
# Document ID: 77 - Topic: Technology Research and Development
# Document ID: 78 - Topic: Technology Research and Development
# Document ID: 79 - Topic: Technology Research and Development
# Document ID: 80 - Topic: Technology Research and Development
# Document ID: 81 - Topic: Technology Research and Development
# Document ID: 82 - Topic: Technology Research and Development
# Document ID: 83 - Topic: Technology Research and Development
# Document ID: 84 - Topic: Technology Research and Development
# Document ID: 85 - Topic: Technology Research and Development
# Document ID: 86 - Topic: Technology Research and Development
# Document ID: 87 - Topic: Technology Research and Development
# Document ID: 88 - Topic: Technology Research and Development
# Document ID: 89 - Topic: Technology Research and Development
# Document ID: 90 - Topic: Technology Research and Development
# Document ID: 91 - Topic: Technology Research and Development
# Document ID: 92 - Topic: Technology Research and Development
# Document ID: 93 - Topic: Technology Research and Development
# Document ID: 94 - Topic: Technology Research and Development
# Document ID: 95 - Topic: Technology Research and Development
# Document ID: 96 - Topic: Technology Research and Development
# Document ID: 97 - Topic: Technology Research and Development
# Document ID: 98 - Topic: Technology Research and Development
# Document ID: 99 - Topic: Technology Research and Development
# Document ID: 100 - Topic: Technology Research and Development
# Document ID: 101 - Topic: Technology Research and Development
# Document ID: 102 - Topic: Technology Research and Development
# Document ID: 103 - Topic: Technology Research and Development
# Document ID: 104 - Topic: Technology Research and Development
# Document ID: 105 - Topic: Technology Research and Development
# Document ID: 106 - Topic: Technology Research and Development
# Document ID: 107 - Topic: Technology Research and Development
# Document ID: 108 - Topic: Technology Research and Development
# Document ID: 109 - Topic: Technology Research and Development
# Document ID: 110 - Topic: Technology Research and Development
# Document ID: 111 - Topic: Technology Research and Development
# Document ID: 112 - Topic: Technology Research and Development
# Document ID: 113 - Topic: Technology Research and Development
# Document ID: 114 - Topic: Technology Research and Development
# Document ID: 115 - Topic: Technology Research and Development
# Document ID: 116 - Topic: Technology Research and Development
# Document ID: 117 - Topic: Technology Research and Development
# Document ID: 118 - Topic: Technology Research and Development
# Document ID: 119 - Topic: Technology Research and Development
# Document ID: 120 - Topic: Technology Research and Development
# Document ID: 121 - Topic: Technology Research and Development
# Document ID: 122 - Topic: Technology Research and Development
# Document ID: 123 - Topic: Technology Research and Development
# Document ID: 124 - Topic: Technology Research and Development
# Document ID: 125 - Topic: Technology Research and Development
# Document ID: 126 - Topic: Technology Research and Development
# Document ID: 127 - Topic: Technology Research and Development
# Document ID: 128 - Topic: Technology Research and Development
# Document ID: 129 - Topic: Technology Research and Development
# Document ID: 130 - Topic: Technology Research and Development
# Document ID: 131 - Topic: Technology Research and Development
# Document ID: 132 - Topic: Technology Research and Development
# Document ID: 133 - Topic: Technology Research and Development
# Document ID: 134 - Topic: Technology Research and Development
# Document ID: 135 - Topic: Technology Research and Development
# Document ID: 136 - Topic: Technology Research and Development
# Document ID: 137 - Topic: Technology Research and Development
# Document ID: 138 - Topic: Technology Research and Development
# Document ID: 139 - Topic: Technology Research and Development
# Document ID: 140 - Topic: Technology Research and Development
# Document ID: 141 - Topic: Technology Research and Development
# Document ID: 142 - Topic: Technology Research and Development
# Document ID: 143 - Topic: Technology Research and Development
# Document ID: 144 - Topic: Technology Research and Development
# Document ID: 145 - Topic: Technology Research and Development
# Document ID: 146 - Topic: Technology Research and Development
# Document ID: 147 - Topic: Technology Research and Development
# Document ID: 148 - Topic: Technology Research and Development
# Document ID: 149 - Topic: Technology Research and Development
# Document ID: 150 - Topic: Technology Research and Development
# Document ID: 151 - Topic: Technology Research and Development
# Document ID: 152 - Topic: Technology Research and Development
# Document ID: 153 - Topic: Technology Research and Development
# Document ID: 154 - Topic: Technology Research and Development
# Document ID: 155 - Topic: Technology Research and Development
# Document ID: 156 - Topic: Technology Research and Development
# Document ID: 157 - Topic: Technology Research and Development
# Document ID: 158 - Topic: Technology Research and Development
# Document ID: 159 - Topic: Technology Research and Development
# Document ID: 160 - Topic: Technology Research and Development
# Document ID: 161 - Topic: Technology Research and Development
# Document ID: 162 - Topic: Technology Research and Development
# Document ID: 163 - Topic: Technology Research and Development
# Document ID: 164 - Topic: Technology Research and Development
# Document ID: 165 - Topic: Technology Research and Development
# Document ID: 166 - Topic: Technology Research and Development
# Document ID: 167 - Topic: Technology Research and Development
# Document ID: 168 - Topic: Technology Research and Development
# Document ID: 169 - Topic: Technology Research and Development
# Document ID: 170 - Topic: Technology Research and Development
# Document ID: 171 - Topic: Technology Research and Development
# Document ID: 172 - Topic: Technology Research and Development
# Document ID: 173 - Topic: Technology Research and Development
# Document ID: 174 - Topic: Technology Research and Development
# Document ID: 175 - Topic: Technology Research and Development
# Document ID: 176 - Topic: Technology Research and Development
# Document ID: 177 - Topic: Technology Research and Development
# Document ID: 178 - Topic: Technology Research and Development
# Document ID: 179 - Topic: Technology Research and Development
# Document ID: 180 - Topic: Technology Research and Development
# Document ID: 181 - Topic: Technology Research and Development
# Document ID: 182 - Topic: Technology Research and Development
# Document ID: 183 - Topic: Technology Research and Development
# Document ID: 184 - Topic: Technology Research and Development
# Document ID: 185 - Topic: Technology Research and Development
# Document ID: 186 - Topic: Technology Research and Development
# Document ID: 187 - Topic: Technology Research and Development
# Document ID: 188 - Topic: Technology Research and Development
# Document ID: 189 - Topic: Technology Research and Development
# Document ID: 190 - Topic: Technology Research and Development
# Document ID: 191 - Topic: Technology Research and Development
# Document ID: 192 - Topic: Technology Research and Development
# Document ID: 193 - Topic: Technology Research and Development
# Document ID: 194 - Topic: Technology Research and Development
# Document ID: 195 - Topic: Technology Research and Development
# Document ID: 196 - Topic: Technology Research and Development
# Document ID: 197 - Topic: Technology Research and Development
# Document ID: 198 - Topic: Technology Research and Development
# Document ID: 199 - Topic: Technology Research and Development
# Document ID: 200 - Topic: Technology Research and Development
# Document ID: 201 - Topic: Technology Research and Development
# Document ID: 202 - Topic: Technology Research and Development
# Document ID: 203 - Topic: Technology Research and Development
# Document ID: 204 - Topic: Technology Research and Development
# Document ID: 205 - Topic: Technology Research and Development
# Document ID: 206 - Topic: Technology Research and Development
# Document ID: 207 - Topic: Technology Research and Development
# Document ID: 208 - Topic: Technology Research and Development
# Document ID: 209 - Topic: Technology Research and Development
# Document ID: 210 - Topic: Technology Research and Development
# Document ID: 211 - Topic: Technology Research and Development
# Document ID: 212 - Topic: Technology Research and Development
# Document ID: 213 - Topic: Technology Research and Development
# Document ID: 214 - Topic: Technology Research and Development
# Document ID: 215 - Topic: Technology Research and Development
# Document ID: 216 - Topic: Technology Research and Development
# Document ID: 217 - Topic: Technology Research and Development
# Document ID: 218 - Topic: Technology Research and Development
# Document ID: 219 - Topic: Technology Research and Development
# Document ID: 220 - Topic: Technology Research and Development
# Document ID: 221 - Topic: Technology Research and Development
# Document ID: 222 - Topic: Technology Research and Development
# Document ID: 223 - Topic: Technology Research and Development
# Document ID: 224 - Topic: Technology Research and Development
# Document ID: 225 - Topic: Technology Research and Development
# Document ID: 226 - Topic: Technology Research and Development
# Document ID: 227 - Topic: Technology Research and Development
# Document ID: 228 - Topic: Technology Research and Development
# Document ID: 229 - Topic: Technology Research and Development
# Document ID: 230 - Topic: Technology Research and Development
# Document ID: 231 - Topic: Technology Research and Development
# Document ID: 232 - Topic: Technology Research and Development
# Document ID: 233 - Topic: Technology Research and Development
# Document ID: 234 - Topic: Technology Research and Development
# Document ID: 235 - Topic: Technology Research and Development
# Document ID: 236 - Topic: Technology Research and Development
# Document ID: 237 - Topic: Technology Research and Development
# Document ID: 238 - Topic: Technology Research and Development
# Document ID: 239 - Topic: Technology Research and Development
# Document ID: 240 - Topic: Technology Research and Development
# Document ID: 241 - Topic: Technology Research and Development
# Document ID: 242 - Topic: Technology Research and Development
# Document ID: 243 - Topic: Technology Research and Development
# Document ID: 244 - Topic: Technology Research and Development
# Document ID: 245 - Topic: Technology Research and Development
# Document ID: 246 - Topic: Technology Research and Development
# Document ID: 247 - Topic: Technology Research and Development
# Document ID: 248 - Topic: Technology Research and Development
# Document ID: 249 - Topic: Technology Research and Development
# Document ID: 250 - Topic: Technology Research and Development
# Document ID: 251 - Topic: Technology Research and Development
# Document ID: 252 - Topic: Technology Research and Development
# Document ID: 253 - Topic: Technology Research and Development
# Document ID: 254 - Topic: Technology Research and Development
# Document ID: 255 - Topic: Technology Research and Development
# Document ID: 256 - Topic: Technology Research and Development
# Document ID: 257 - Topic: Technology Research and Development
# Document ID: 258 - Topic: Technology Research and Development
# Document ID: 259 - Topic: Technology Research and Development
# Document ID: 260 - Topic: Technology Research and Development
# Document ID: 261 - Topic: Technology Research and Development
# Document ID: 262 - Topic: Technology Research and Development
# Document ID: 263 - Topic: Technology Research and Development
# Document ID: 264 - Topic: Technology Research and Development
# Document ID: 265 - Topic: Technology Research and Development
# Document ID: 266 - Topic: Technology Research and Development
# Document ID: 267 - Topic: Technology Research and Development
# Document ID: 268 - Topic: Technology Research and Development
# Document ID: 269 - Topic: Technology Research and Development
# Document ID: 270 - Topic: Technology Research and Development
# Document ID: 271 - Topic: Technology Research and Development
# Document ID: 272 - Topic: Technology Research and Development
# Document ID: 273 - Topic: Technology Research and Development
# Document ID: 274 - Topic: Technology Research and Development
# Document ID: 275 - Topic: Technology Research and Development
# Document ID: 276 - Topic: Technology Research and Development
# Document ID: 277 - Topic: Technology Research and Development
# Document ID: 278 - Topic: Technology Research and Development
# Document ID: 279 - Topic: Technology Research and Development
# Document ID: 280 - Topic: Technology Research and Development
# Document ID: 281 - Topic: Technology Research and Development
# Document ID: 282 - Topic: Technology Research and Development
# Document ID: 283 - Topic: Technology Research and Development
# Document ID: 284 - Topic: Technology Research and Development
# Document ID: 285 - Topic: Technology Research and Development
# Document ID: 286 - Topic: Technology Research and Development
# Document ID: 287 - Topic: Technology Research and Development
# Document ID: 288 - Topic: Technology Research and Development
# Document ID: 289 - Topic: Technology Research and Development
# Document ID: 290 - Topic: Technology Research and Development
# Document ID: 291 - Topic: Technology Research and Development
# Document ID: 292 - Topic: Technology Research and Development
# Document ID: 293 - Topic: Technology Research and Development
# Document ID: 294 - Topic: Technology Research and Development
# Document ID: 295 - Topic: Technology Research and Development
# Document ID: 296 - Topic: Technology Research and Development
# Document ID: 297 - Topic: Technology Research and Development
# Document ID: 298 - Topic: Technology Research and Development
# Document ID: 299 - Topic: Technology Research and Development

# %% [markdown]
# 7. Visualizing the LDA topics

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation
import matplotlib.pyplot as plt
import numpy as np

# Define topic names
topic_names = [
    "Technology and Innovation",
    "Politics and Security",
    "Legal and Regulatory Compliance",
    "Cruptocurrency and Blockchain Technology",
    "Communication and Collaboration Tools",
    "Financial Markets and Investment Strategies",
    "Corporate Ventures and Partnerships",
    "Healthcare and Medical Practices",
    "AI. and Technology Companies",
    "Corporate Governance and Compliance Issues",
    "Social Impact and Ethical Considerations",
    "Technology Research and Development",
]

# Plot the top words for each topic
def plot_top_words(model, feature_names, n_top_words, title, topic_names=None):
    num_topics = len(model.components_)
    ncols = min(num_topics, 4)  # Maximum number of columns
    nrows = (num_topics // ncols) + (num_topics % ncols > 0)  # Calculate number of rows
    
    fig, axes = plt.subplots(nrows, ncols, figsize=(5 * ncols, 3 * nrows), sharex=True)
    axes = axes.flatten()  # Flatten axes for easy iteration
    
    for topic_idx, topic in enumerate(model.components_):
        if topic_idx >= num_topics:  # Check if topic index exceeds the number of topics
            break  # Exit loop if all topics have been plotted
        
        top_features_ind = topic.argsort()[:-n_top_words - 1:-1]
        top_features = [feature_names[i] for i in top_features_ind]
        weights = topic[top_features_ind]
        
        ax = axes[topic_idx]
        if topic_names is not None:
            ax.set_title(topic_names[topic_idx], fontsize=15)
        else:
            ax.set_title(f'Topic {topic_idx}', fontsize=15)
        ax.barh(top_features, weights, height=0.7)
        ax.invert_yaxis()
        ax.tick_params(axis='both', which='major', labelsize=12)
        for i in 'top right left'.split():
            ax.spines[i].set_visible(False)
        fig.suptitle(title, fontsize=20)

    # Hide any extra subplots
    for i in range(num_topics, len(axes)):
        axes[i].axis('off')
        
    plt.subplots_adjust(top=0.90, bottom=0.05, wspace=0.90, hspace=0.3)
    plt.show()

# Example usage: Assuming you have already defined and fitted the LDA model
num_topics = 12  # Assuming you have 15 topics
feature_names = pd.read_csv('tfidf_vectorized_300.csv').columns
num_top_words = 10  # Assuming you want to display 10 top words per topic
lda_model = LatentDirichletAllocation(n_components=num_topics, random_state=42)
lda_model.fit(csr_matrix(pd.read_csv('tfidf_vectorized_300.csv').values))
plot_top_words(lda_model, feature_names, n_top_words=num_top_words, title='Top Words Per Topic', topic_names=topic_names)

# %%
from wordcloud import WordCloud

# Create word clouds for each topic
def plot_word_clouds(model, feature_names, num_topics, n_top_words, topic_names=None):
    # Create subplots based on the number of topics
    ncols = min(num_topics, 4)  # Maximum number of columns
    nrows = (num_topics // ncols) + (num_topics % ncols > 0)  # Calculate number of rows
    fig, axes = plt.subplots(nrows, ncols, figsize=(15, 3 * nrows), sharex=True, sharey=True)
    axes = axes.flatten()  # Flatten the axes for easy iteration
    
    # Generate a word cloud for each topic
    for topic_idx, topic in enumerate(model.components_):
        # Get the top words and their weights for the current topic
        top_features_ind = topic.argsort()[:-n_top_words - 1:-1]
        top_features = {feature_names[i]: topic[i] for i in top_features_ind}
        
        # Generate a word cloud for the current topic
        wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(top_features)
        
        # Plot the word cloud
        ax = axes[topic_idx]
        if topic_names is not None:
            ax.set_title(topic_names[topic_idx], fontsize=15)
        else:
            ax.set_title(f'Topic {topic_idx}', fontsize=15)
        ax.imshow(wordcloud, interpolation='bilinear')
        ax.axis('off')
    
    # Hide any extra subplots
    for i in range(num_topics, len(axes)):
        axes[i].axis('off')
    
    plt.tight_layout()
    plt.show()

# Example usage: Assuming you have already defined and fitted the LDA model
num_topics = 12  # Assuming you have 15 topics
feature_names = pd.read_csv('tfidf_vectorized_300.csv').columns
num_top_words = 10  # Assuming you want to display 20 top words per topic
lda_model = LatentDirichletAllocation(n_components=num_topics, random_state=42)
lda_model.fit(csr_matrix(pd.read_csv('tfidf_vectorized_300.csv').values))
plot_word_clouds(lda_model, feature_names, num_topics=num_topics, n_top_words=num_top_words, topic_names=topic_names)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Get topic distribution for each document
topic_distribution = lda_model.transform(csr_matrix(pd.read_csv('tfidf_vectorized_300.csv').values))

# Calculate the average topic distribution across all documents
average_topic_distribution = topic_distribution.mean(axis=0)

# Define topic names
topic_names = [
    "Technology and Innovation",
    "Politics and Security",
    "Legal and Regulatory Compliance",
    "Cruptocurrency and Blockchain Technology",
    "Communication and Collaboration Tools",
    "Financial Markets and Investment Strategies",
    "Corporate Ventures and Partnerships",
    "Healthcare and Medical Practices",
    "AI. and Technology Companies",
    "Corporate Governance and Compliance Issues",
    "Social Impact and Ethical Considerations",
    "Technology Research and Development",
]

# Plot the average topic distribution with topic names
plt.figure(figsize=(12, 6))
plt.bar(range(len(average_topic_distribution)), average_topic_distribution, color='orange')
plt.xlabel('Topic', fontsize=16)
plt.ylabel('Average Proportion', fontsize=14)
plt.title('Average Topic Distribution Across Documents', fontsize=16)
plt.xticks(range(len(average_topic_distribution)), topic_names, rotation=45, ha='right')
plt.tight_layout()  # Adjust layout to prevent overlapping
plt.show()

# %%
import pandas as pd

# Get feature names
feature_names = pd.read_csv('tfidf_vectorized_300.csv').columns

# Number of top words per topic to display
n_top_words = 20

# Extract the topics and their terms
topics = []
for topic_idx, topic in enumerate(lda_model.components_):
    top_features_ind = topic.argsort()[:-n_top_words - 1:-1]
    top_features = [feature_names[i] for i in top_features_ind]
    topics.append(f"Topic {topic_idx}")

# Create a dataframe to display the topics
df_topics = pd.DataFrame({
    'Topic': [f"Topic {i}" for i in range(num_topics)],
    'Terms per Topic': [" ".join([feature_names[i] for i in lda_model.components_[topic_idx].argsort()[:-n_top_words - 1:-1]]) for topic_idx in range(num_topics)]
})

# Display the dataframe
print(df_topics)
# Out:
#        Topic                                    Terms per Topic
# 0    Topic 0  salle water desantis linkedin iowa llama auste...
# 1    Topic 1  merchat repair cruise shop cent oracle paintin...
# 2    Topic 2  amd ftc facstamp orth cpu fac peds solo travel...
# 3    Topic 3  reben gene ar mckinsey profluent classroom cri...
# 4    Topic 4  guardian journalism plastic button zoom keyboa...
# 5    Topic 5  kapture metaverse secondary cx axios crore cap...
# 6    Topic 6  tenen amd animal bag guidebook walmart supplie...
# 7    Topic 7  inflection sora reddit rephrase pi hoffman cha...
# 8    Topic 8  casey ernie marion lozano fork sydelabs davis ...
# 9    Topic 9  highmark agility lensa mensch sachs mistral pi...
# 10  Topic 10  patient doctor travel hospital llm bot iphone ...
# 11  Topic 11  ai company new technology openai india abstrac...
